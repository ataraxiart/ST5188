# %%
# !pip install d2l torch torchvision
# Out:
# Requirement already satisfied: d2l in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (1.0.3)
# Requirement already satisfied: torch in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (2.6.0)
# Requirement already satisfied: torchvision in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: jupyter==1.0.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from d2l) (1.0.0)
# Requirement already satisfied: numpy==1.23.5 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from d2l) (1.23.5)
# Requirement already satisfied: matplotlib==3.7.2 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from d2l) (3.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from d2l) (0.1.6)
# Requirement already satisfied: requests==2.31.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from d2l) (2.31.0)
# Requirement already satisfied: pandas==2.0.3 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from d2l) (2.0.3)
# Requirement already satisfied: scipy==1.10.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from d2l) (1.10.1)
# Requirement already satisfied: notebook in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (7.4.0)
# Requirement already satisfied: qtconsole in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (5.6.1)
# Requirement already satisfied: jupyter-console in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (7.16.6)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.29.5)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (8.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (2.9.0.post0)
# Requirement already satisfied: traitlets in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from matplotlib-inline==0.1.6->d2l) (5.14.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from pandas==2.0.3->d2l) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from pandas==2.0.3->d2l) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from requests==2.31.0->d2l) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from requests==2.31.0->d2l) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from requests==2.31.0->d2l) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from requests==2.31.0->d2l) (2025.1.31)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.7.2->d2l) (1.17.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.35.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.7.2)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (6.4.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (3.0.14)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (3.0.50)
# Requirement already satisfied: pygments in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (2.19.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->d2l) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.5.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.0rc0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (4.4.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from qtconsole->jupyter==1.0.0->d2l) (2.4.3)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->d2l) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->d2l) (1.4.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (5.2.1)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (4.9.0)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l) (4.3.7)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (2.2.5)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (75.8.0)
# Requirement already satisfied: tomli>=1.2.2 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (2.2.1)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->d2l) (2.21.1)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->d2l) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->d2l) (2.5)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->d2l) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->d2l) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.3)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/d2l_env/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.9.0.20241206)

# %%
import torch
from torch import nn
from d2l import torch as d2l
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.optim as optim

# %%
## THIS CODE IS TO CREATE THE TENSOR FOR THE TRAINING DATA ##

changi_df = pd.read_csv('../../../Data/Final/Imputation/imp_train_set.csv')

# Pivot to create a time series for each (x, y)
changi_pivot = changi_df.pivot(index=['x', 'y'], columns='Date', values='Value')
#print (changi_pivot)

# Reset index to keep (x, y) as columns
changi_pivot = changi_pivot.reset_index()

# Convert time columns back into a NumPy array
ts_changi = changi_pivot.iloc[:, 2:].values  # Ignore first two columns (x, y)
loc_changi = changi_pivot.iloc[:, :2].values  # Store coordinates

# Standardization with Z-score normalisation
changi_mean_LST = ts_changi.mean()
changi_std_LST = ts_changi.std()
ts_changi = (ts_changi - changi_mean_LST) / changi_std_LST 

# Convert to PyTorch tensor wiith extra dimension for LST
X_train_tensor_changi = torch.tensor(ts_changi, dtype=torch.float32).unsqueeze(-1)

X_train_changi = X_train_tensor_changi
y_train_changi = X_train_tensor_changi[:, 1:, :]

# %% [markdown]
# #### Without dropout

# %%
## THIS CODE IS TO DEFINE THE LSTM MODEL ##

class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)  # Fully connected layer

    def forward(self, x):
        lstm_out, _ = self.lstm(x)  # LSTM output
        out = self.fc(lstm_out)  # Fully connected layer for final prediction
        return out

# %%
## THIS CODE IS TO TRAIN THE MODEL ##
torch.manual_seed(5188)

model = LSTMPredictor() # Model
criterion = nn.MSELoss() # Loss function to track performance over epochs
optimizer = optim.Adam(model.parameters(), lr=0.001) # Adam optimizer (can be switched)

# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()

    predictions = model(X_train_changi)

    loss = criterion(predictions[:, :-1, :], y_train_changi)
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0: # Print loss every 10 epochs
        print(f"Epoch {epoch}/{num_epochs}, Loss: {loss.item():.4f}")
# Out:
# Epoch 0/100, Loss: 1.0082
# Epoch 10/100, Loss: 0.9866
# Epoch 20/100, Loss: 0.9414
# Epoch 30/100, Loss: 0.9111
# Epoch 40/100, Loss: 0.9006
# Epoch 50/100, Loss: 0.8959
# Epoch 60/100, Loss: 0.8907
# Epoch 70/100, Loss: 0.8838
# Epoch 80/100, Loss: 0.8766
# Epoch 90/100, Loss: 0.8602

# %%
## THIS CODE IS FOR FORECASTING##

model.eval()
torch.manual_seed(5188)

with torch.no_grad():
    X_pred_changi = model(X_train_changi)  # Forecast next steps
    X_pred_changi= X_pred_changi[:, -12:, :]  # Extract last 12 bimonthly periods (2023-2024)

# Convert predictions to a NumPy array
X_pred_changi_np = X_pred_changi.squeeze().cpu().numpy()

# **Denormalize predictions**
X_pred_changi_np = (X_pred_changi_np * changi_std_LST) + changi_mean_LST  # Convert back to original from scaled values

# Define bimonthly periods
bimonthly_periods = [
    "Jan-Feb 2023", "Mar-Apr 2023", "May-Jun 2023", "Jul-Aug 2023", "Sep-Oct 2023", "Nov-Dec 2023",
    "Jan-Feb 2024", "Mar-Apr 2024", "May-Jun 2024", "Jul-Aug 2024", "Sep-Oct 2024", "Nov-Dec 2024"
]

# Create a long-format DataFrame
changi_pred_df = pd.DataFrame({
    "x": np.repeat(loc_changi[:, 0], len(bimonthly_periods)),  # Use stored locations
    "y": np.repeat(loc_changi[:, 1], len(bimonthly_periods)),  
    "Date": bimonthly_periods * len(loc_changi),
    "Predicted_LST": X_pred_changi_np.flatten()  # Store denormalized values
})

# changi_pred_df.to_csv('changi_pred_long.csv', index=False) # Save to CSV for RMSE

# %%
## THIS CODE IS TO CALCULATE RMSE ##

# Load predicted and true values
true_df = changi_pred_df
pred_df = pd.read_csv("../../../Data/Final/TT Split/changi_test_long.csv")

# Merge predicted and actual values
merged_df = true_df.merge(pred_df, on=["x", "y", "Date"], suffixes=("_true", "_pred"))

# Define the mapping between date and forecast step
date_to_horizon = {
    "Jan-Feb 2023": 1,
    "May-Jun 2023": 3,
    "Nov-Dec 2023": 6,
    "May-Jun 2024": 9,
    "Nov-Dec 2024": 12
}

# Filter only relevant dates
selected_dates = list(date_to_horizon.keys())
filtered_df = merged_df[merged_df["Date"].isin(selected_dates)].copy()

# Map forecast horizon
filtered_df["Forecast horizon"] = filtered_df["Date"].map(date_to_horizon)

# Compute RMSE per forecast horizon
rmse_by_horizon = filtered_df.groupby("Forecast horizon").apply(
    lambda g: np.sqrt(np.mean((g["Predicted_LST"] - g["Value"]) ** 2))
).reset_index(name="LSTM w/o dropout")

# Compute overall RMSE
overall_rmse = np.sqrt(np.mean((filtered_df["Predicted_LST"] - filtered_df["Value"]) ** 2))
overall_row = pd.DataFrame({
    "Forecast horizon": ["Overall"],
    "LSTM w/o dropout": [overall_rmse]
})

# Combine RMSEs
final_rmse_df = pd.concat([rmse_by_horizon, overall_row], ignore_index=True)

# Save the table
final_rmse_df.to_csv("rmse_lstm_no_dropout.csv", index=False)

# Show the result
print(final_rmse_df)
# Out:
#   Forecast horizon  LSTM w/o dropout
# 0                1          5.503483
# 1                3          1.722315
# 2                6          2.933474
# 3                9          1.149421
# 4               12          3.917198
# 5          Overall          3.421274
# C:\Users\naomi\AppData\Local\Temp\ipykernel_13664\1001673750.py:28: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rmse_by_horizon = filtered_df.groupby("Forecast horizon").apply(

# %% [markdown]
# #### With dropout

# %%
class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1, dropout=0.2):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            dropout=dropout if num_layers > 1 else 0.0,  # dropout only works if num_layers > 1
            batch_first=True
        )
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = self.dropout(lstm_out)
        out = self.fc(out)
        return out

# %%
# Initialize model
torch.manual_seed(5188)
model = LSTMPredictor()

# Define loss function and optimizer with weight decay
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-6)  # Added weight decay

# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()

    predictions = model(X_train_changi)
    predictions = predictions[:, :-1, :]

    loss = criterion(predictions, y_train_changi)
    loss.backward()
    optimizer.step()
    
    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{num_epochs}, Loss: {loss.item():.4f}")
# Out:
# Epoch 0/100, Loss: 1.0084
# Epoch 10/100, Loss: 0.9869
# Epoch 20/100, Loss: 0.9423
# Epoch 30/100, Loss: 0.9128
# Epoch 40/100, Loss: 0.9030
# Epoch 50/100, Loss: 0.8990
# Epoch 60/100, Loss: 0.8946
# Epoch 70/100, Loss: 0.8892
# Epoch 80/100, Loss: 0.8835
# Epoch 90/100, Loss: 0.8752

# %%
# Forecasting
model.eval()
torch.manual_seed(5188)
with torch.no_grad():
    X_pred_changi = model(X_train_changi)
    X_pred_changi = X_pred_changi[:, -12:, :]

# Denormalize predictions
X_pred_changi_np = (X_pred_changi.squeeze().cpu().numpy() * changi_std_LST) + changi_mean_LST

# Define bimonthly periods
bimonthly_periods = [
    "Jan-Feb 2023", "Mar-Apr 2023", "May-Jun 2023", "Jul-Aug 2023", "Sep-Oct 2023", "Nov-Dec 2023",
    "Jan-Feb 2024", "Mar-Apr 2024", "May-Jun 2024", "Jul-Aug 2024", "Sep-Oct 2024", "Nov-Dec 2024"
]

# Create DataFrame for predictions
changi_pred_df = pd.DataFrame({
    "x": np.repeat(loc_changi[:, 0], len(bimonthly_periods)),
    "y": np.repeat(loc_changi[:, 1], len(bimonthly_periods)),  
    "Date": bimonthly_periods * len(loc_changi),
    "Predicted_LST": X_pred_changi_np.flatten()
})

# %%
## THIS CODE IS TO CALCULATE RMSE ##

# Load predicted and true values
true_df = changi_pred_df
pred_df = pd.read_csv("../../../Data/Final/TT Split/changi_test_long.csv")

# Merge predicted and actual values
merged_df = true_df.merge(pred_df, on=["x", "y", "Date"], suffixes=("_true", "_pred"))

# Define the mapping between date and forecast step
date_to_horizon = {
    "Jan-Feb 2023": 1,
    "May-Jun 2023": 3,
    "Nov-Dec 2023": 6,
    "May-Jun 2024": 9,
    "Nov-Dec 2024": 12
}

# Filter only relevant dates
selected_dates = list(date_to_horizon.keys())
filtered_df = merged_df[merged_df["Date"].isin(selected_dates)].copy()

# Map forecast horizon
filtered_df["Forecast horizon"] = filtered_df["Date"].map(date_to_horizon)

# Compute RMSE per forecast horizon
rmse_by_horizon = filtered_df.groupby("Forecast horizon").apply(
    lambda g: np.sqrt(np.mean((g["Predicted_LST"] - g["Value"]) ** 2))
).reset_index(name="LSTM w/o dropout")

# Compute overall RMSE
overall_rmse = np.sqrt(np.mean((filtered_df["Predicted_LST"] - filtered_df["Value"]) ** 2))
overall_row = pd.DataFrame({
    "Forecast horizon": ["Overall"],
    "LSTM w/o dropout": [overall_rmse]
})

# Combine RMSEs
final_rmse_df = pd.concat([rmse_by_horizon, overall_row], ignore_index=True)

# Save the table
final_rmse_df.to_csv("rmse_lstm_dropout.csv", index=False)

# Show the result
print(final_rmse_df)
# Out:
#   Forecast horizon  LSTM w/o dropout
# 0                1          5.476454
# 1                3          1.959899
# 2                6          3.121004
# 3                9          1.100429
# 4               12          3.983294
# 5          Overall          3.482843
# C:\Users\naomi\AppData\Local\Temp\ipykernel_13664\98453864.py:27: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rmse_by_horizon = filtered_df.groupby("Forecast horizon").apply(
