# %%
import torch
from torch import nn
import torch.optim as optim
import torch.nn as nn
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from dateutil.relativedelta import relativedelta
import geopandas as gpd
from shapely.geometry import Polygon, Point
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("../../../Data/Final/Imputation/changi_imp_final.csv")
print(df.head())
# Out:
#             x         y          Date      Value
# 0  103.964566  1.350459  Mar-Apr 2000  23.775064
# 1  103.964566  1.351269  Mar-Apr 2000  23.403744
# 2  103.964566  1.352079  Mar-Apr 2000  22.966872
# 3  103.964566  1.352889  Mar-Apr 2000  22.417757
# 4  103.965377  1.348838  Mar-Apr 2000  23.699749

# %%
## THIS CODE IS TO REFORMAT THE TIME INDEX IN THE DATASET ##

# Function to create a time index
def create_time_index(df):
    bimonthly_map = {"Jan-Feb": 1, "Mar-Apr": 2, "May-Jun": 3, "Jul-Aug": 4, "Sep-Oct": 5, "Nov-Dec": 6}
    
    df["Year"] = df["Date"].str[-4:].astype(int)  # Extract year
    df["Period"] = df["Date"].str[:-5].map(bimonthly_map)  # Extract period and map it

    df["time_index"] = (df["Year"] - 2000) * 6 + df["Period"]  # Compute time index
    df = df.drop(columns=["Year", "Period"])  # Drop extra columns
    
    return df

# Apply time index transformation
df = create_time_index(df)

# %%
## THIS CODE IS TO FILTER A RANDOM SAMPLE OF 100 COORDINATES INSIDE A BOUNDING BOX ##

np.random.seed(5188)  # Set random seed for reproducibility

# Define the bounding box (replace with actual values)
coordinates = [103.98, 104.05, 1.32, 1.38]  # Example bounding box for Changi
bbox = Polygon([
    (coordinates[0], coordinates[2]), 
    (coordinates[1], coordinates[2]), 
    (coordinates[1], coordinates[3]), 
    (coordinates[0], coordinates[3]), 
    (coordinates[0], coordinates[2])
])

# Function to filter 100 coordinates inside bounding box
def filter_by_geography(df, bbox, seed=5188, n=100):
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df["x"], df["y"]), crs="EPSG:4326")
    filtered_gdf = gdf[gdf.within(bbox)]
    
    # Select 100 unique coordinates
    sampled_coords = filtered_gdf[['x', 'y']].drop_duplicates().sample(n=n, random_state=seed)
    filtered_df = df.merge(sampled_coords, on=['x', 'y'])
    
    return filtered_df

# Apply filtering
df = filter_by_geography(df, bbox)

# Keep only relevant columns
df = df[["x", "y", "Date", "Value", "time_index"]]

# # Save the filtered dataset
# df.to_csv("filtered_changi.csv", index=False)
# print("Filtered dataset saved as filtered_changi.csv")

## To ensure that the same 100 coordinates are used check the unique (x,y) pairs in the filtered dataset ##
unique_coords = df[['x', 'y']].drop_duplicates()
print(f"Number of unique coordinates: {len(unique_coords)}")
# Out:
# Number of unique coordinates: 100

# %%
## THIS CODE IS TO EXTRACT ALL POSSIBLE WINDOWS OF SIZE = 12 ##

# Define sequence length
sequence_length = 12 * 6
target_length = 12  # Predict the next 12 time steps

# Group by (x, y) and process each time series separately
grouped = df.groupby(["x", "y"])

# Lists to store input sequences and target sequences separately
input_sequences = []
target_sequences = []
locations = []

# Iterate over each coordinate group
for (x, y), group in grouped:
    # Sort by time index
    group = group.sort_values(by="time_index")

    # Extract LST values
    values = group["Value"].values

    # Generate sequences
    for i in range(len(values) - sequence_length - target_length + 1):
        input_seq = values[i : i + sequence_length]  # Past values
        target_seq = values[i + sequence_length : i + sequence_length + target_length]  # Next 12 values
        
        # Store sequences separately
        input_sequences.append([x, y] + list(input_seq))
        target_sequences.append([x, y] + list(target_seq))
        locations.append([x, y])

# Define column names
input_columns = ["x", "y"] + [f"LST_t-{i}" for i in range(sequence_length, 0, -1)]
target_columns = ["x", "y"] + [f"Target_t+{i}" for i in range(1, target_length + 1)]

# Convert to DataFrames
input_df = pd.DataFrame(input_sequences, columns=input_columns)
target_df = pd.DataFrame(target_sequences, columns=target_columns)

# # Save input and target sequences as separate CSV files
# input_df.to_csv("changi_inputs_9.csv", index=False)
# target_df.to_csv("changi_targets_10.csv", index=False)

# %%
## THIS FUNCTION IS TO CREATE THE 10 RANDOM TRAIN-TEST SAMPLES ##

np.random.seed(5188)

# Function to create a time index
def create_time_index(df):
    bimonthly_map = {"Jan-Feb": 1, "Mar-Apr": 2, "May-Jun": 3, "Jul-Aug": 4, "Sep-Oct": 5, "Nov-Dec": 6}
    df["Year"] = df["Date"].str[-4:].astype(int)  # Extract year
    df["Period"] = df["Date"].str[:-5].map(bimonthly_map)  # Extract period and map it
    df["time_index"] = (df["Year"] - 2000) * 6 + df["Period"]  # Compute time index
    df = df.drop(columns=["Year", "Period"])  # Drop extra columns
    return df

df = create_time_index(df)

# Select 100 random unique coordinate pairs
unique_coords = df[['x', 'y']].drop_duplicates().sample(n=100, random_state=5188)
selected_df = df.merge(unique_coords, on=['x', 'y'])

# Get valid start indices for 9-year training windows
min_time = selected_df["time_index"].min()
max_time = selected_df["time_index"].max()
valid_start_times = np.arange(min_time, max_time - (12 * 6 + 2 * 6) + 1)

# Randomly sample 10 different start times
sampled_start_times = np.random.choice(valid_start_times, 10, replace=False)

# Extract train and test sets for each sampled start time
samples = []
for start_time in sampled_start_times:
    train_end_time = start_time + (12 * 6) - 1
    test_end_time = train_end_time + (2 * 6)
    
    train_set = selected_df[(selected_df["time_index"] >= start_time) & (selected_df["time_index"] <= train_end_time)]
    test_set = selected_df[(selected_df["time_index"] > train_end_time) & (selected_df["time_index"] <= test_end_time)]
    
    samples.append((train_set, test_set))


# # Save sampled train-test sets
# for i, (train_set, test_set) in enumerate(samples):
#     train_set.to_csv(f"train_sample_{i+1}.csv", index=False)
#     test_set.to_csv(f"test_sample_{i+1}.csv", index=False)

# %% [markdown]
# ### Without dropout

# %%
## THIS CODE IS TO CREATE THE LSTM ##

class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = self.fc(lstm_out)
        return out

# %%
## THIS CODE IS TO TRAIN THE LSTM ##
torch.manual_seed(5188)

# Function to prepare sequences for LSTM
def create_lstm_sequences(series, seq_length):
    X, y = [], []
    for i in range(len(series) - seq_length):
        X.append(series[i:i+seq_length])
        y.append(series[i+1:i+seq_length+1])
    return np.array(X), np.array(y)

# Training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
seq_length = 12

# Initialize RMSE tracker
rmse_stats = {
    "1st": [], "3rd": [], "6th": [], "9th": [], "12th": [], "Overall": []
}

# Iterate over every sampled train-test set
for sample_idx, (train_set, test_set) in enumerate(samples):
    
    value_series = train_set['Value'].values.astype(np.float32)
    test_values = test_set['Value'].values.astype(np.float32)[:12]  # Only next 12 values

    mean, std = value_series.mean(), value_series.std()
    value_series_norm = (value_series - mean) / std

    X_seq, y_seq = create_lstm_sequences(value_series_norm.reshape(-1, 1), seq_length)
    X_train = torch.tensor(X_seq, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq, dtype=torch.float32).to(device)

    model = LSTMPredictor().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        output = model(X_train)
        loss = criterion(output[:, :-1, :], y_train[:, 1:, :])
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"Sample {sample_idx+1}, Epoch {epoch}, Loss: {loss.item():.4f}")

    model.eval()
    with torch.no_grad():
        input_seq = torch.tensor(value_series_norm[-seq_length:].reshape(1, seq_length, 1), dtype=torch.float32).to(device)
        preds = []
        for _ in range(12):
            pred = model(input_seq)[:, -1:, :]
            preds.append(pred.item())
            input_seq = torch.cat((input_seq[:, 1:, :], pred), dim=1)

    preds = np.array(preds) * std + mean

    # Calculate RMSEs
    for step, label in zip([0, 2, 5, 8, 11], ["1st", "3rd", "6th", "9th", "12th"]):
        rmse = np.sqrt(mean_squared_error([test_values[step]], [preds[step]]))
        rmse_stats[label].append(rmse)

    all_rmse = np.sqrt(mean_squared_error(test_values, preds))
    rmse_stats["Overall"].append(all_rmse)

# Compute average RMSE across samples
rmse_df_12 = pd.DataFrame({k: [np.mean(v)] for k, v in rmse_stats.items()}).T
rmse_df_12.columns = ["Window = 12"]
rmse_df_12.index.name = "Forecast horizon"
print("\nAverage RMSE per forecast step:")
print(rmse_df_12)
rmse_df_12.to_csv("rmse_12.csv")
# Out:
# Sample 1, Epoch 0, Loss: 1.0033
# Sample 1, Epoch 10, Loss: 0.9074
# Sample 1, Epoch 20, Loss: 0.5181
# Sample 1, Epoch 30, Loss: 0.4803
# Sample 1, Epoch 40, Loss: 0.4483
# Sample 1, Epoch 50, Loss: 0.4015
# Sample 1, Epoch 60, Loss: 0.3545
# Sample 1, Epoch 70, Loss: 0.3116
# Sample 1, Epoch 80, Loss: 0.2888
# Sample 1, Epoch 90, Loss: 0.2739
# Sample 2, Epoch 0, Loss: 1.0012
# Sample 2, Epoch 10, Loss: 0.9155
# Sample 2, Epoch 20, Loss: 0.5344
# Sample 2, Epoch 30, Loss: 0.4954
# Sample 2, Epoch 40, Loss: 0.4623
# Sample 2, Epoch 50, Loss: 0.4130
# Sample 2, Epoch 60, Loss: 0.3628
# Sample 2, Epoch 70, Loss: 0.3173
# Sample 2, Epoch 80, Loss: 0.2918
# Sample 2, Epoch 90, Loss: 0.2749
# Sample 3, Epoch 0, Loss: 1.0066
# Sample 3, Epoch 10, Loss: 0.9367
# Sample 3, Epoch 20, Loss: 0.6038
# Sample 3, Epoch 30, Loss: 0.5235
# Sample 3, Epoch 40, Loss: 0.4555
# Sample 3, Epoch 50, Loss: 0.3930
# Sample 3, Epoch 60, Loss: 0.3326
# Sample 3, Epoch 70, Loss: 0.2898
# Sample 3, Epoch 80, Loss: 0.2683
# Sample 3, Epoch 90, Loss: 0.2512
# Sample 4, Epoch 0, Loss: 1.0044
# Sample 4, Epoch 10, Loss: 0.9336
# Sample 4, Epoch 20, Loss: 0.5537
# Sample 4, Epoch 30, Loss: 0.4931
# Sample 4, Epoch 40, Loss: 0.4607
# Sample 4, Epoch 50, Loss: 0.4115
# Sample 4, Epoch 60, Loss: 0.3651
# Sample 4, Epoch 70, Loss: 0.3207
# Sample 4, Epoch 80, Loss: 0.2896
# Sample 4, Epoch 90, Loss: 0.2745
# Sample 5, Epoch 0, Loss: 1.0234
# Sample 5, Epoch 10, Loss: 0.9390
# Sample 5, Epoch 20, Loss: 0.6221
# Sample 5, Epoch 30, Loss: 0.5272
# Sample 5, Epoch 40, Loss: 0.4355
# Sample 5, Epoch 50, Loss: 0.3749
# Sample 5, Epoch 60, Loss: 0.3266
# Sample 5, Epoch 70, Loss: 0.2978
# Sample 5, Epoch 80, Loss: 0.2769
# Sample 5, Epoch 90, Loss: 0.2622
# Sample 6, Epoch 0, Loss: 1.0358
# Sample 6, Epoch 10, Loss: 0.9419
# Sample 6, Epoch 20, Loss: 0.6474
# Sample 6, Epoch 30, Loss: 0.5364
# Sample 6, Epoch 40, Loss: 0.4488
# Sample 6, Epoch 50, Loss: 0.3849
# Sample 6, Epoch 60, Loss: 0.3273
# Sample 6, Epoch 70, Loss: 0.2908
# Sample 6, Epoch 80, Loss: 0.2691
# Sample 6, Epoch 90, Loss: 0.2531
# Sample 7, Epoch 0, Loss: 1.0067
# Sample 7, Epoch 10, Loss: 0.9249
# Sample 7, Epoch 20, Loss: 0.5592
# Sample 7, Epoch 30, Loss: 0.5105
# Sample 7, Epoch 40, Loss: 0.4735
# Sample 7, Epoch 50, Loss: 0.4172
# Sample 7, Epoch 60, Loss: 0.3629
# Sample 7, Epoch 70, Loss: 0.3134
# Sample 7, Epoch 80, Loss: 0.2904
# Sample 7, Epoch 90, Loss: 0.2724
# Sample 8, Epoch 0, Loss: 0.9985
# Sample 8, Epoch 10, Loss: 0.8943
# Sample 8, Epoch 20, Loss: 0.5230
# Sample 8, Epoch 30, Loss: 0.4679
# Sample 8, Epoch 40, Loss: 0.4305
# Sample 8, Epoch 50, Loss: 0.3824
# Sample 8, Epoch 60, Loss: 0.3387
# Sample 8, Epoch 70, Loss: 0.3010
# Sample 8, Epoch 80, Loss: 0.2820
# Sample 8, Epoch 90, Loss: 0.2672
# Sample 9, Epoch 0, Loss: 1.0037
# Sample 9, Epoch 10, Loss: 0.8880
# Sample 9, Epoch 20, Loss: 0.5243
# Sample 9, Epoch 30, Loss: 0.4776
# Sample 9, Epoch 40, Loss: 0.4334
# Sample 9, Epoch 50, Loss: 0.3761
# Sample 9, Epoch 60, Loss: 0.3245
# Sample 9, Epoch 70, Loss: 0.2939
# Sample 9, Epoch 80, Loss: 0.2751
# Sample 9, Epoch 90, Loss: 0.2596
# Sample 10, Epoch 0, Loss: 1.0067
# Sample 10, Epoch 10, Loss: 0.9304
# Sample 10, Epoch 20, Loss: 0.5532
# Sample 10, Epoch 30, Loss: 0.5105
# Sample 10, Epoch 40, Loss: 0.4805
# Sample 10, Epoch 50, Loss: 0.4339
# Sample 10, Epoch 60, Loss: 0.3886
# Sample 10, Epoch 70, Loss: 0.3487
# Sample 10, Epoch 80, Loss: 0.3253
# Sample 10, Epoch 90, Loss: 0.3099
#
# Average RMSE per forecast step:
#                   Window = 12
# Forecast horizon
# 1st                  2.768495
# 3rd                  2.240341
# 6th                  2.270532
# 9th                  2.168599
# 12th                 2.422563
# Overall              2.534161

# %% [markdown]
# ### With dropout

# %%
## THIS CODE IS TO CREATE THE LSTM ##

class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1, dropout=0.2):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers, 
            batch_first=True, dropout=dropout
        )
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = self.fc(lstm_out)
        return out

# %%
## THIS CODE IS TO TRAIN THE LSTM ##
torch.manual_seed(5188)

# Function to prepare sequences for LSTM
def create_lstm_sequences(series, seq_length):
    X, y = [], []
    for i in range(len(series) - seq_length):
        X.append(series[i:i+seq_length])
        y.append(series[i+1:i+seq_length+1])
    return np.array(X), np.array(y)

# Training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
seq_length = 12

# Initialize RMSE tracker
rmse_stats = {
    "1st": [], "3rd": [], "6th": [], "9th": [], "12th": [], "Overall": []
}

# Iterate over each sampled train-test set
for sample_idx, (train_set, test_set) in enumerate(samples):
    
    value_series = train_set['Value'].values.astype(np.float32)
    test_values = test_set['Value'].values.astype(np.float32)[:12]  # Only next 12 values

    mean, std = value_series.mean(), value_series.std()
    value_series_norm = (value_series - mean) / std

    X_seq, y_seq = create_lstm_sequences(value_series_norm.reshape(-1, 1), seq_length)
    X_train = torch.tensor(X_seq, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq, dtype=torch.float32).to(device)

    model = LSTMPredictor().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-6)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        output = model(X_train)
        loss = criterion(output[:, :-1, :], y_train[:, 1:, :])
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"Sample {sample_idx+1}, Epoch {epoch}, Loss: {loss.item():.4f}")

    model.eval()
    with torch.no_grad():
        input_seq = torch.tensor(value_series_norm[-seq_length:].reshape(1, seq_length, 1), dtype=torch.float32).to(device)
        preds = []
        for _ in range(12):
            pred = model(input_seq)[:, -1:, :]
            preds.append(pred.item())
            input_seq = torch.cat((input_seq[:, 1:, :], pred), dim=1)

    preds = np.array(preds) * std + mean

    # Calculate RMSEs
    for step, label in zip([0, 2, 5, 8, 11], ["1st", "3rd", "6th", "9th", "12th"]):
        rmse = np.sqrt(mean_squared_error([test_values[step]], [preds[step]]))
        rmse_stats[label].append(rmse)

    all_rmse = np.sqrt(mean_squared_error(test_values, preds))
    rmse_stats["Overall"].append(all_rmse)

# Compute average RMSE across samples
rmse_df_12_dropout = pd.DataFrame({k: [np.mean(v)] for k, v in rmse_stats.items()}).T
rmse_df_12_dropout.columns = ["Window = 12"]
rmse_df_12_dropout.index.name = "Forecast horizon"
print("\nAverage RMSE per forecast step:")
print(rmse_df_12_dropout)
rmse_df_12_dropout.to_csv("rmse_dropout_12.csv")
# Out:
# Sample 1, Epoch 0, Loss: 1.0033
# Sample 1, Epoch 10, Loss: 0.9077
# Sample 1, Epoch 20, Loss: 0.5192
# Sample 1, Epoch 30, Loss: 0.4815
# Sample 1, Epoch 40, Loss: 0.4501
# Sample 1, Epoch 50, Loss: 0.4037
# Sample 1, Epoch 60, Loss: 0.3574
# Sample 1, Epoch 70, Loss: 0.3160
# Sample 1, Epoch 80, Loss: 0.2934
# Sample 1, Epoch 90, Loss: 0.2788
# Sample 2, Epoch 0, Loss: 1.0011
# Sample 2, Epoch 10, Loss: 0.9156
# Sample 2, Epoch 20, Loss: 0.5358
# Sample 2, Epoch 30, Loss: 0.4968
# Sample 2, Epoch 40, Loss: 0.4641
# Sample 2, Epoch 50, Loss: 0.4146
# Sample 2, Epoch 60, Loss: 0.3653
# Sample 2, Epoch 70, Loss: 0.3202
# Sample 2, Epoch 80, Loss: 0.2956
# Sample 2, Epoch 90, Loss: 0.2801
# Sample 3, Epoch 0, Loss: 1.0066
# Sample 3, Epoch 10, Loss: 0.9370
# Sample 3, Epoch 20, Loss: 0.6056
# Sample 3, Epoch 30, Loss: 0.5255
# Sample 3, Epoch 40, Loss: 0.4583
# Sample 3, Epoch 50, Loss: 0.3968
# Sample 3, Epoch 60, Loss: 0.3379
# Sample 3, Epoch 70, Loss: 0.2954
# Sample 3, Epoch 80, Loss: 0.2748
# Sample 3, Epoch 90, Loss: 0.2584
# Sample 4, Epoch 0, Loss: 1.0044
# Sample 4, Epoch 10, Loss: 0.9337
# Sample 4, Epoch 20, Loss: 0.5553
# Sample 4, Epoch 30, Loss: 0.4946
# Sample 4, Epoch 40, Loss: 0.4626
# Sample 4, Epoch 50, Loss: 0.4136
# Sample 4, Epoch 60, Loss: 0.3674
# Sample 4, Epoch 70, Loss: 0.3240
# Sample 4, Epoch 80, Loss: 0.2942
# Sample 4, Epoch 90, Loss: 0.2797
# Sample 5, Epoch 0, Loss: 1.0234
# Sample 5, Epoch 10, Loss: 0.9391
# Sample 5, Epoch 20, Loss: 0.6228
# Sample 5, Epoch 30, Loss: 0.5285
# Sample 5, Epoch 40, Loss: 0.4376
# Sample 5, Epoch 50, Loss: 0.3780
# Sample 5, Epoch 60, Loss: 0.3301
# Sample 5, Epoch 70, Loss: 0.3031
# Sample 5, Epoch 80, Loss: 0.2825
# Sample 5, Epoch 90, Loss: 0.2687
# Sample 6, Epoch 0, Loss: 1.0358
# Sample 6, Epoch 10, Loss: 0.9422
# Sample 6, Epoch 20, Loss: 0.6494
# Sample 6, Epoch 30, Loss: 0.5384
# Sample 6, Epoch 40, Loss: 0.4511
# Sample 6, Epoch 50, Loss: 0.3876
# Sample 6, Epoch 60, Loss: 0.3313
# Sample 6, Epoch 70, Loss: 0.2954
# Sample 6, Epoch 80, Loss: 0.2752
# Sample 6, Epoch 90, Loss: 0.2591
# Sample 7, Epoch 0, Loss: 1.0068
# Sample 7, Epoch 10, Loss: 0.9251
# Sample 7, Epoch 20, Loss: 0.5607
# Sample 7, Epoch 30, Loss: 0.5116
# Sample 7, Epoch 40, Loss: 0.4746
# Sample 7, Epoch 50, Loss: 0.4189
# Sample 7, Epoch 60, Loss: 0.3657
# Sample 7, Epoch 70, Loss: 0.3173
# Sample 7, Epoch 80, Loss: 0.2950
# Sample 7, Epoch 90, Loss: 0.2780
# Sample 8, Epoch 0, Loss: 0.9985
# Sample 8, Epoch 10, Loss: 0.8946
# Sample 8, Epoch 20, Loss: 0.5243
# Sample 8, Epoch 30, Loss: 0.4690
# Sample 8, Epoch 40, Loss: 0.4321
# Sample 8, Epoch 50, Loss: 0.3849
# Sample 8, Epoch 60, Loss: 0.3418
# Sample 8, Epoch 70, Loss: 0.3053
# Sample 8, Epoch 80, Loss: 0.2870
# Sample 8, Epoch 90, Loss: 0.2726
# Sample 9, Epoch 0, Loss: 1.0037
# Sample 9, Epoch 10, Loss: 0.8885
# Sample 9, Epoch 20, Loss: 0.5254
# Sample 9, Epoch 30, Loss: 0.4796
# Sample 9, Epoch 40, Loss: 0.4364
# Sample 9, Epoch 50, Loss: 0.3790
# Sample 9, Epoch 60, Loss: 0.3283
# Sample 9, Epoch 70, Loss: 0.2985
# Sample 9, Epoch 80, Loss: 0.2813
# Sample 9, Epoch 90, Loss: 0.2663
# Sample 10, Epoch 0, Loss: 1.0067
# Sample 10, Epoch 10, Loss: 0.9305
# Sample 10, Epoch 20, Loss: 0.5547
# Sample 10, Epoch 30, Loss: 0.5115
# Sample 10, Epoch 40, Loss: 0.4819
# Sample 10, Epoch 50, Loss: 0.4357
# Sample 10, Epoch 60, Loss: 0.3911
# Sample 10, Epoch 70, Loss: 0.3514
# Sample 10, Epoch 80, Loss: 0.3294
# Sample 10, Epoch 90, Loss: 0.3144
#
# Average RMSE per forecast step:
#                   Window = 12
# Forecast horizon
# 1st                  2.792225
# 3rd                  2.233332
# 6th                  2.274422
# 9th                  2.168445
# 12th                 2.446722
# Overall              2.539567
