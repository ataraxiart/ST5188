# %%
# to check if the required packages are installed before calling the libraries required

import subprocess
import sys

def install_and_import(package):
    try:
        __import__(package)
    except ImportError:
        print(f"{package} not found. Installing...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        print(f"{package} installed successfully.")
        __import__(package)

# Example usage
install_and_import("torch")
install_and_import("numpy")
install_and_import("pandas")
install_and_import("dateutil")
install_and_import("geopandas")
install_and_import("shapely")
install_and_import("sklearn")

# %%
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

import numpy as np
import pandas as pd

from dateutil.relativedelta import relativedelta
import geopandas as gpd
from shapely.geometry import Polygon, Point
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("../../../Data/Final/Imputation/changi_imp_final.csv")
print(df.head())
# Out:
#             x         y          Date      Value
# 0  103.964566  1.350459  Mar-Apr 2000  23.775064
# 1  103.964566  1.351269  Mar-Apr 2000  23.403744
# 2  103.964566  1.352079  Mar-Apr 2000  22.966872
# 3  103.964566  1.352889  Mar-Apr 2000  22.417757
# 4  103.965377  1.348838  Mar-Apr 2000  23.699749

# %%
## THIS CODE IS TO REFORMAT THE TIME INDEX IN THE DATASET ##

# Function to create a time index
def create_time_index(df):
    bimonthly_map = {"Jan-Feb": 1, "Mar-Apr": 2, "May-Jun": 3, "Jul-Aug": 4, "Sep-Oct": 5, "Nov-Dec": 6}
    
    df["Year"] = df["Date"].str[-4:].astype(int)  # Extract year
    df["Period"] = df["Date"].str[:-5].map(bimonthly_map)  # Extract period and map it

    df["time_index"] = (df["Year"] - 2000) * 6 + df["Period"]  # Compute time index
    df = df.drop(columns=["Year", "Period"])  # Drop extra columns
    
    return df

# Apply time index transformation
df = create_time_index(df)

# %%
## THIS CODE IS TO FILTER A RANDOM SAMPLE OF 100 COORDINATES INSIDE A BOUNDING BOX ##

np.random.seed(5188)  # Set random seed for reproducibility

# Define the bounding box (replace with actual values)
coordinates = [103.98, 104.05, 1.32, 1.38]  # Example bounding box for Changi
bbox = Polygon([
    (coordinates[0], coordinates[2]), 
    (coordinates[1], coordinates[2]), 
    (coordinates[1], coordinates[3]), 
    (coordinates[0], coordinates[3]), 
    (coordinates[0], coordinates[2])
])

# Function to filter 100 coordinates inside bounding box
def filter_by_geography(df, bbox, seed=5188, n=100):
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df["x"], df["y"]), crs="EPSG:4326")
    filtered_gdf = gdf[gdf.within(bbox)]
    
    # Select 100 unique coordinates
    sampled_coords = filtered_gdf[['x', 'y']].drop_duplicates().sample(n=n, random_state=seed)
    filtered_df = df.merge(sampled_coords, on=['x', 'y'])
    
    return filtered_df

# Apply filtering
df = filter_by_geography(df, bbox)

# Keep only relevant columns
df = df[["x", "y", "Date", "Value", "time_index"]]

# # Save the filtered dataset
# df.to_csv("filtered_changi.csv", index=False)
# print("Filtered dataset saved as filtered_changi.csv")

## To ensure that the same 100 coordinates are used check the unique (x,y) pairs in the filtered dataset ##
unique_coords = df[['x', 'y']].drop_duplicates()
print(f"Number of unique coordinates: {len(unique_coords)}")
# Out:
# Number of unique coordinates: 100

# %%
## THIS CODE IS TO EXTRACT ALL POSSIBLE WINDOWS OF SIZE = 9 ##

# Define sequence length
sequence_length = 9 * 6
target_length = 12  # Predict the next 12 time steps

# Group by (x, y) and process each time series separately
grouped = df.groupby(["x", "y"])

# Lists to store input sequences and target sequences separately
input_sequences = []
target_sequences = []
locations = []

# Iterate over each coordinate group
for (x, y), group in grouped:
    # Sort by time index
    group = group.sort_values(by="time_index")

    # Extract LST values
    values = group["Value"].values

    # Generate sequences
    for i in range(len(values) - sequence_length - target_length + 1):
        input_seq = values[i : i + sequence_length]  # Past values
        target_seq = values[i + sequence_length : i + sequence_length + target_length]  # Next 12 values
        
        # Store sequences separately
        input_sequences.append([x, y] + list(input_seq))
        target_sequences.append([x, y] + list(target_seq))
        locations.append([x, y])

# Define column names
input_columns = ["x", "y"] + [f"LST_t-{i}" for i in range(sequence_length, 0, -1)]
target_columns = ["x", "y"] + [f"Target_t+{i}" for i in range(1, target_length + 1)]

# Convert to DataFrames
input_df = pd.DataFrame(input_sequences, columns=input_columns)
target_df = pd.DataFrame(target_sequences, columns=target_columns)

# # Save input and target sequences as separate CSV files
# input_df.to_csv("changi_inputs_9.csv", index=False)
# target_df.to_csv("changi_targets_10.csv", index=False)

# %%
## THIS FUNCTION IS TO CREATE THE 10 RANDOM TRAIN-TEST SAMPLES ##

np.random.seed(5188)

# Function to create a time index
def create_time_index(df):
    bimonthly_map = {"Jan-Feb": 1, "Mar-Apr": 2, "May-Jun": 3, "Jul-Aug": 4, "Sep-Oct": 5, "Nov-Dec": 6}
    df["Year"] = df["Date"].str[-4:].astype(int)  # Extract year
    df["Period"] = df["Date"].str[:-5].map(bimonthly_map)  # Extract period and map it
    df["time_index"] = (df["Year"] - 2000) * 6 + df["Period"]  # Compute time index
    df = df.drop(columns=["Year", "Period"])  # Drop extra columns
    return df

df = create_time_index(df)

# Select 100 random unique coordinate pairs
unique_coords = df[['x', 'y']].drop_duplicates().sample(n=100, random_state=5188)
selected_df = df.merge(unique_coords, on=['x', 'y'])

# Get valid start indices for 9-year training windows
min_time = selected_df["time_index"].min()
max_time = selected_df["time_index"].max()
valid_start_times = np.arange(min_time, max_time - (9 * 6 + 2 * 6) + 1)

# Randomly sample 10 different start times
sampled_start_times = np.random.choice(valid_start_times, 10, replace=False)

# Extract train and test sets for each sampled start time
samples = []
for start_time in sampled_start_times:
    train_end_time = start_time + (9 * 6) - 1
    test_end_time = train_end_time + (2 * 6)
    
    train_set = selected_df[(selected_df["time_index"] >= start_time) & (selected_df["time_index"] <= train_end_time)]
    test_set = selected_df[(selected_df["time_index"] > train_end_time) & (selected_df["time_index"] <= test_end_time)]
    
    samples.append((train_set, test_set))


# # Save sampled train-test sets
# for i, (train_set, test_set) in enumerate(samples):
#     train_set.to_csv(f"train_sample_{i+1}.csv", index=False)
#     test_set.to_csv(f"test_sample_{i+1}.csv", index=False)

# %% [markdown]
# ### Without dropout

# %%
## THIS CODE IS TO CREATE THE LSTM ##

class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = self.fc(lstm_out)
        return out

# %%
## THIS CODE IS TO TRAIN THE LSTM ##
torch.manual_seed(5188)

# Function to prepare sequences for LSTM
def create_lstm_sequences(series, seq_length):
    X, y = [], []
    for i in range(len(series) - seq_length):
        X.append(series[i:i+seq_length])
        y.append(series[i+1:i+seq_length+1])
    return np.array(X), np.array(y)

# Training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
seq_length = 12

# Initialize RMSE tracker
rmse_stats = {
    "1st": [], "3rd": [], "6th": [], "9th": [], "12th": [], "Overall": []
}

# Iterate over each sampled train-test set
for sample_idx, (train_set, test_set) in enumerate(samples):
    
    value_series = train_set['Value'].values.astype(np.float32)
    test_values = test_set['Value'].values.astype(np.float32)[:12]  # Only next 12 values

    mean, std = value_series.mean(), value_series.std()
    value_series_norm = (value_series - mean) / std

    X_seq, y_seq = create_lstm_sequences(value_series_norm.reshape(-1, 1), seq_length)
    X_train = torch.tensor(X_seq, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq, dtype=torch.float32).to(device)

    model = LSTMPredictor().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        output = model(X_train)
        loss = criterion(output[:, :-1, :], y_train[:, 1:, :])
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"Sample {sample_idx+1}, Epoch {epoch}, Loss: {loss.item():.4f}")

    model.eval()
    with torch.no_grad():
        input_seq = torch.tensor(value_series_norm[-seq_length:].reshape(1, seq_length, 1), dtype=torch.float32).to(device)
        preds = []
        for _ in range(12):
            pred = model(input_seq)[:, -1:, :]
            preds.append(pred.item())
            input_seq = torch.cat((input_seq[:, 1:, :], pred), dim=1)

    preds = np.array(preds) * std + mean

    # Calculate RMSEs
    for step, label in zip([0, 2, 5, 8, 11], ["1st", "3rd", "6th", "9th", "12th"]):
        rmse = np.sqrt(mean_squared_error([test_values[step]], [preds[step]]))
        rmse_stats[label].append(rmse)

    all_rmse = np.sqrt(mean_squared_error(test_values, preds))
    rmse_stats["Overall"].append(all_rmse)

# Compute average RMSE across samples
rmse_df_9 = pd.DataFrame({k: [np.mean(v)] for k, v in rmse_stats.items()}).T
rmse_df_9.columns = ["Window = 9"]
rmse_df_9.index.name = "Forecast horizon"
print("\nAverage RMSE per forecast step:")
print(rmse_df_9)
rmse_df_9.to_csv("rmse_9.csv")
# Out:
# Sample 1, Epoch 0, Loss: 1.0040
# Sample 1, Epoch 10, Loss: 0.9070
# Sample 1, Epoch 20, Loss: 0.5077
# Sample 1, Epoch 30, Loss: 0.4704
# Sample 1, Epoch 40, Loss: 0.4390
# Sample 1, Epoch 50, Loss: 0.3923
# Sample 1, Epoch 60, Loss: 0.3457
# Sample 1, Epoch 70, Loss: 0.3031
# Sample 1, Epoch 80, Loss: 0.2790
# Sample 1, Epoch 90, Loss: 0.2646
# Sample 2, Epoch 0, Loss: 1.0015
# Sample 2, Epoch 10, Loss: 0.9133
# Sample 2, Epoch 20, Loss: 0.5259
# Sample 2, Epoch 30, Loss: 0.4899
# Sample 2, Epoch 40, Loss: 0.4554
# Sample 2, Epoch 50, Loss: 0.4006
# Sample 2, Epoch 60, Loss: 0.3459
# Sample 2, Epoch 70, Loss: 0.2953
# Sample 2, Epoch 80, Loss: 0.2677
# Sample 2, Epoch 90, Loss: 0.2507
# Sample 3, Epoch 0, Loss: 1.0032
# Sample 3, Epoch 10, Loss: 0.9371
# Sample 3, Epoch 20, Loss: 0.6091
# Sample 3, Epoch 30, Loss: 0.5390
# Sample 3, Epoch 40, Loss: 0.4807
# Sample 3, Epoch 50, Loss: 0.4313
# Sample 3, Epoch 60, Loss: 0.3861
# Sample 3, Epoch 70, Loss: 0.3535
# Sample 3, Epoch 80, Loss: 0.3331
# Sample 3, Epoch 90, Loss: 0.3178
# Sample 4, Epoch 0, Loss: 1.0032
# Sample 4, Epoch 10, Loss: 0.9350
# Sample 4, Epoch 20, Loss: 0.5713
# Sample 4, Epoch 30, Loss: 0.5141
# Sample 4, Epoch 40, Loss: 0.4834
# Sample 4, Epoch 50, Loss: 0.4364
# Sample 4, Epoch 60, Loss: 0.3913
# Sample 4, Epoch 70, Loss: 0.3481
# Sample 4, Epoch 80, Loss: 0.3199
# Sample 4, Epoch 90, Loss: 0.3055
# Sample 5, Epoch 0, Loss: 1.0119
# Sample 5, Epoch 10, Loss: 0.9278
# Sample 5, Epoch 20, Loss: 0.6172
# Sample 5, Epoch 30, Loss: 0.5118
# Sample 5, Epoch 40, Loss: 0.4194
# Sample 5, Epoch 50, Loss: 0.3522
# Sample 5, Epoch 60, Loss: 0.3001
# Sample 5, Epoch 70, Loss: 0.2682
# Sample 5, Epoch 80, Loss: 0.2471
# Sample 5, Epoch 90, Loss: 0.2315
# Sample 6, Epoch 0, Loss: 1.0362
# Sample 6, Epoch 10, Loss: 0.9406
# Sample 6, Epoch 20, Loss: 0.6332
# Sample 6, Epoch 30, Loss: 0.5256
# Sample 6, Epoch 40, Loss: 0.4350
# Sample 6, Epoch 50, Loss: 0.3698
# Sample 6, Epoch 60, Loss: 0.3136
# Sample 6, Epoch 70, Loss: 0.2772
# Sample 6, Epoch 80, Loss: 0.2542
# Sample 6, Epoch 90, Loss: 0.2376
# Sample 7, Epoch 0, Loss: 1.0082
# Sample 7, Epoch 10, Loss: 0.9250
# Sample 7, Epoch 20, Loss: 0.5571
# Sample 7, Epoch 30, Loss: 0.5057
# Sample 7, Epoch 40, Loss: 0.4679
# Sample 7, Epoch 50, Loss: 0.4102
# Sample 7, Epoch 60, Loss: 0.3549
# Sample 7, Epoch 70, Loss: 0.3041
# Sample 7, Epoch 80, Loss: 0.2806
# Sample 7, Epoch 90, Loss: 0.2619
# Sample 8, Epoch 0, Loss: 0.9932
# Sample 8, Epoch 10, Loss: 0.8876
# Sample 8, Epoch 20, Loss: 0.5134
# Sample 8, Epoch 30, Loss: 0.4592
# Sample 8, Epoch 40, Loss: 0.4177
# Sample 8, Epoch 50, Loss: 0.3644
# Sample 8, Epoch 60, Loss: 0.3161
# Sample 8, Epoch 70, Loss: 0.2789
# Sample 8, Epoch 80, Loss: 0.2598
# Sample 8, Epoch 90, Loss: 0.2437
# Sample 9, Epoch 0, Loss: 1.0041
# Sample 9, Epoch 10, Loss: 0.8870
# Sample 9, Epoch 20, Loss: 0.5138
# Sample 9, Epoch 30, Loss: 0.4677
# Sample 9, Epoch 40, Loss: 0.4255
# Sample 9, Epoch 50, Loss: 0.3709
# Sample 9, Epoch 60, Loss: 0.3212
# Sample 9, Epoch 70, Loss: 0.2888
# Sample 9, Epoch 80, Loss: 0.2699
# Sample 9, Epoch 90, Loss: 0.2542
# Sample 10, Epoch 0, Loss: 1.0059
# Sample 10, Epoch 10, Loss: 0.9274
# Sample 10, Epoch 20, Loss: 0.5336
# Sample 10, Epoch 30, Loss: 0.4838
# Sample 10, Epoch 40, Loss: 0.4509
# Sample 10, Epoch 50, Loss: 0.4001
# Sample 10, Epoch 60, Loss: 0.3515
# Sample 10, Epoch 70, Loss: 0.3073
# Sample 10, Epoch 80, Loss: 0.2812
# Sample 10, Epoch 90, Loss: 0.2653
#
# Average RMSE per forecast step:
#                   Window = 9
# Forecast horizon
# 1st                 3.551837
# 3rd                 3.564647
# 6th                 3.178261
# 9th                 3.570742
# 12th                3.121743
# Overall             3.524548

# %% [markdown]
# ### With dropout

# %%
## THIS CODE IS TO CREATE THE LSTM ##

class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1, dropout=0.2):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers, 
            batch_first=True, dropout=dropout
        )
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = self.fc(lstm_out)
        return out

# %%
## THIS CODE IS TO TRAIN THE LSTM ##
torch.manual_seed(5188)

# Function to prepare sequences for LSTM
def create_lstm_sequences(series, seq_length):
    X, y = [], []
    for i in range(len(series) - seq_length):
        X.append(series[i:i+seq_length])
        y.append(series[i+1:i+seq_length+1])
    return np.array(X), np.array(y)

# Training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
seq_length = 12

# Initialize RMSE tracker
rmse_stats = {
    "1st": [], "3rd": [], "6th": [], "9th": [], "12th": [], "Overall": []
}

# Iterate over each sampled train-test set
for sample_idx, (train_set, test_set) in enumerate(samples):
    
    value_series = train_set['Value'].values.astype(np.float32)
    test_values = test_set['Value'].values.astype(np.float32)[:12]  # Only next 12 values

    mean, std = value_series.mean(), value_series.std()
    value_series_norm = (value_series - mean) / std

    X_seq, y_seq = create_lstm_sequences(value_series_norm.reshape(-1, 1), seq_length)
    X_train = torch.tensor(X_seq, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq, dtype=torch.float32).to(device)

    model = LSTMPredictor().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-6)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        output = model(X_train)
        loss = criterion(output[:, :-1, :], y_train[:, 1:, :])
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"Sample {sample_idx+1}, Epoch {epoch}, Loss: {loss.item():.4f}")

    model.eval()
    with torch.no_grad():
        input_seq = torch.tensor(value_series_norm[-seq_length:].reshape(1, seq_length, 1), dtype=torch.float32).to(device)
        preds = []
        for _ in range(12):
            pred = model(input_seq)[:, -1:, :]
            preds.append(pred.item())
            input_seq = torch.cat((input_seq[:, 1:, :], pred), dim=1)

    preds = np.array(preds) * std + mean

    # Calculate RMSEs
    for step, label in zip([0, 2, 5, 8, 11], ["1st", "3rd", "6th", "9th", "12th"]):
        rmse = np.sqrt(mean_squared_error([test_values[step]], [preds[step]]))
        rmse_stats[label].append(rmse)

    all_rmse = np.sqrt(mean_squared_error(test_values, preds))
    rmse_stats["Overall"].append(all_rmse)

# Compute average RMSE across samples
rmse_df_9_dropout = pd.DataFrame({k: [np.mean(v)] for k, v in rmse_stats.items()}).T
rmse_df_9_dropout.columns = ["Window = 9"]
rmse_df_9_dropout.index.name = "Forecast horizon"
print("\nAverage RMSE per forecast step:")
print(rmse_df_9_dropout)
rmse_df_9_dropout.to_csv("rmse_dropout_9.csv")
# Out:
# Sample 1, Epoch 0, Loss: 1.0041
# Sample 1, Epoch 10, Loss: 0.9077
# Sample 1, Epoch 20, Loss: 0.5087
# Sample 1, Epoch 30, Loss: 0.4721
# Sample 1, Epoch 40, Loss: 0.4408
# Sample 1, Epoch 50, Loss: 0.3941
# Sample 1, Epoch 60, Loss: 0.3485
# Sample 1, Epoch 70, Loss: 0.3067
# Sample 1, Epoch 80, Loss: 0.2823
# Sample 1, Epoch 90, Loss: 0.2693
# Sample 2, Epoch 0, Loss: 1.0192
# Sample 2, Epoch 10, Loss: 0.9342
# Sample 2, Epoch 20, Loss: 0.5755
# Sample 2, Epoch 30, Loss: 0.5057
# Sample 2, Epoch 40, Loss: 0.4467
# Sample 2, Epoch 50, Loss: 0.3873
# Sample 2, Epoch 60, Loss: 0.3328
# Sample 2, Epoch 70, Loss: 0.2891
# Sample 2, Epoch 80, Loss: 0.2689
# Sample 2, Epoch 90, Loss: 0.2531
# Sample 3, Epoch 0, Loss: 1.0028
# Sample 3, Epoch 10, Loss: 0.9246
# Sample 3, Epoch 20, Loss: 0.5614
# Sample 3, Epoch 30, Loss: 0.5167
# Sample 3, Epoch 40, Loss: 0.4874
# Sample 3, Epoch 50, Loss: 0.4455
# Sample 3, Epoch 60, Loss: 0.4051
# Sample 3, Epoch 70, Loss: 0.3687
# Sample 3, Epoch 80, Loss: 0.3447
# Sample 3, Epoch 90, Loss: 0.3307
# Sample 4, Epoch 0, Loss: 1.0060
# Sample 4, Epoch 10, Loss: 0.9248
# Sample 4, Epoch 20, Loss: 0.5470
# Sample 4, Epoch 30, Loss: 0.5007
# Sample 4, Epoch 40, Loss: 0.4679
# Sample 4, Epoch 50, Loss: 0.4200
# Sample 4, Epoch 60, Loss: 0.3760
# Sample 4, Epoch 70, Loss: 0.3413
# Sample 4, Epoch 80, Loss: 0.3207
# Sample 4, Epoch 90, Loss: 0.3065
# Sample 5, Epoch 0, Loss: 0.9915
# Sample 5, Epoch 10, Loss: 0.8950
# Sample 5, Epoch 20, Loss: 0.5068
# Sample 5, Epoch 30, Loss: 0.4658
# Sample 5, Epoch 40, Loss: 0.4335
# Sample 5, Epoch 50, Loss: 0.3807
# Sample 5, Epoch 60, Loss: 0.3317
# Sample 5, Epoch 70, Loss: 0.2872
# Sample 5, Epoch 80, Loss: 0.2658
# Sample 5, Epoch 90, Loss: 0.2506
# Sample 6, Epoch 0, Loss: 1.0117
# Sample 6, Epoch 10, Loss: 0.9242
# Sample 6, Epoch 20, Loss: 0.5626
# Sample 6, Epoch 30, Loss: 0.4927
# Sample 6, Epoch 40, Loss: 0.4392
# Sample 6, Epoch 50, Loss: 0.3789
# Sample 6, Epoch 60, Loss: 0.3249
# Sample 6, Epoch 70, Loss: 0.2881
# Sample 6, Epoch 80, Loss: 0.2685
# Sample 6, Epoch 90, Loss: 0.2525
# Sample 7, Epoch 0, Loss: 1.0074
# Sample 7, Epoch 10, Loss: 0.9141
# Sample 7, Epoch 20, Loss: 0.5661
# Sample 7, Epoch 30, Loss: 0.4869
# Sample 7, Epoch 40, Loss: 0.4292
# Sample 7, Epoch 50, Loss: 0.3707
# Sample 7, Epoch 60, Loss: 0.3207
# Sample 7, Epoch 70, Loss: 0.2847
# Sample 7, Epoch 80, Loss: 0.2632
# Sample 7, Epoch 90, Loss: 0.2485
# Sample 8, Epoch 0, Loss: 1.0194
# Sample 8, Epoch 10, Loss: 0.9455
# Sample 8, Epoch 20, Loss: 0.6278
# Sample 8, Epoch 30, Loss: 0.5263
# Sample 8, Epoch 40, Loss: 0.4416
# Sample 8, Epoch 50, Loss: 0.3766
# Sample 8, Epoch 60, Loss: 0.3201
# Sample 8, Epoch 70, Loss: 0.2833
# Sample 8, Epoch 80, Loss: 0.2601
# Sample 8, Epoch 90, Loss: 0.2445
# Sample 9, Epoch 0, Loss: 1.0021
# Sample 9, Epoch 10, Loss: 0.9098
# Sample 9, Epoch 20, Loss: 0.5196
# Sample 9, Epoch 30, Loss: 0.4805
# Sample 9, Epoch 40, Loss: 0.4462
# Sample 9, Epoch 50, Loss: 0.3922
# Sample 9, Epoch 60, Loss: 0.3409
# Sample 9, Epoch 70, Loss: 0.2995
# Sample 9, Epoch 80, Loss: 0.2795
# Sample 9, Epoch 90, Loss: 0.2642
# Sample 10, Epoch 0, Loss: 1.0050
# Sample 10, Epoch 10, Loss: 0.9319
# Sample 10, Epoch 20, Loss: 0.5490
# Sample 10, Epoch 30, Loss: 0.4824
# Sample 10, Epoch 40, Loss: 0.4486
# Sample 10, Epoch 50, Loss: 0.3981
# Sample 10, Epoch 60, Loss: 0.3512
# Sample 10, Epoch 70, Loss: 0.3091
# Sample 10, Epoch 80, Loss: 0.2879
# Sample 10, Epoch 90, Loss: 0.2718
#
# Average RMSE per forecast step:
#                   Window = 9
# Forecast horizon
# 1st                 3.484303
# 3rd                 3.464358
# 6th                 2.992024
# 9th                 3.284083
# 12th                2.793883
# Overall             3.368513
