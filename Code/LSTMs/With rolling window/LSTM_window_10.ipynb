# %%
# to check if the required packages are installed before calling the libraries required

import subprocess
import sys

def install_and_import(package):
    try:
        __import__(package)
    except ImportError:
        print(f"{package} not found. Installing...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        print(f"{package} installed successfully.")
        __import__(package)

# Example usage
install_and_import("torch")
install_and_import("numpy")
install_and_import("pandas")
install_and_import("dateutil")
install_and_import("geopandas")
install_and_import("shapely")
install_and_import("sklearn")

# %%
import torch
from torch import nn
import torch.optim as optim
import torch.nn as nn
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from dateutil.relativedelta import relativedelta
import geopandas as gpd
from shapely.geometry import Polygon, Point
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("../../../Data/Final/Imputation/changi_imp_final.csv")
print(df.head())
# Out:
#             x         y          Date      Value
# 0  103.964566  1.350459  Mar-Apr 2000  23.775064
# 1  103.964566  1.351269  Mar-Apr 2000  23.403744
# 2  103.964566  1.352079  Mar-Apr 2000  22.966872
# 3  103.964566  1.352889  Mar-Apr 2000  22.417757
# 4  103.965377  1.348838  Mar-Apr 2000  23.699749

# %%
## THIS CODE IS TO REFORMAT THE TIME INDEX IN THE DATASET ##

# Function to create a time index
def create_time_index(df):
    bimonthly_map = {"Jan-Feb": 1, "Mar-Apr": 2, "May-Jun": 3, "Jul-Aug": 4, "Sep-Oct": 5, "Nov-Dec": 6}
    
    df["Year"] = df["Date"].str[-4:].astype(int)  # Extract year
    df["Period"] = df["Date"].str[:-5].map(bimonthly_map)  # Extract period and map it

    df["time_index"] = (df["Year"] - 2000) * 6 + df["Period"]  # Compute time index
    df = df.drop(columns=["Year", "Period"])  # Drop extra columns
    
    return df

# Apply time index transformation
df = create_time_index(df)

# %%
## THIS CODE IS TO FILTER A RANDOM SAMPLE OF 100 COORDINATES INSIDE A BOUNDING BOX ##

np.random.seed(5188)  # Set random seed for reproducibility

# Define the bounding box (replace with actual values)
coordinates = [103.98, 104.05, 1.32, 1.38]  # Example bounding box for Changi
bbox = Polygon([
    (coordinates[0], coordinates[2]), 
    (coordinates[1], coordinates[2]), 
    (coordinates[1], coordinates[3]), 
    (coordinates[0], coordinates[3]), 
    (coordinates[0], coordinates[2])
])

# Function to filter 100 coordinates inside bounding box
def filter_by_geography(df, bbox, seed=5188, n=100):
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df["x"], df["y"]), crs="EPSG:4326")
    filtered_gdf = gdf[gdf.within(bbox)]
    
    # Select 100 unique coordinates
    sampled_coords = filtered_gdf[['x', 'y']].drop_duplicates().sample(n=n, random_state=seed)
    filtered_df = df.merge(sampled_coords, on=['x', 'y'])
    
    return filtered_df

# Apply filtering
df = filter_by_geography(df, bbox)

# Keep only relevant columns
df = df[["x", "y", "Date", "Value", "time_index"]]

# # Save the filtered dataset
# df.to_csv("filtered_changi.csv", index=False)
# print("Filtered dataset saved as filtered_changi.csv")

## To ensure that the same 100 coordinates are used check the unique (x,y) pairs in the filtered dataset ##
unique_coords = df[['x', 'y']].drop_duplicates()
print(f"Number of unique coordinates: {len(unique_coords)}")
# Out:
# Number of unique coordinates: 100

# %%
## THIS CODE IS TO EXTRACT ALL POSSIBLE WINDOWS OF SIZE = 10 ##

# Define sequence length
sequence_length = 10 * 6
target_length = 12  # Predict the next 12 time steps

# Group by (x, y) and process each time series separately
grouped = df.groupby(["x", "y"])

# Lists to store input sequences and target sequences separately
input_sequences = []
target_sequences = []
locations = []

# Iterate over each coordinate group
for (x, y), group in grouped:
    # Sort by time index
    group = group.sort_values(by="time_index")

    # Extract LST values
    values = group["Value"].values

    # Generate sequences
    for i in range(len(values) - sequence_length - target_length + 1):
        input_seq = values[i : i + sequence_length]  # Past values
        target_seq = values[i + sequence_length : i + sequence_length + target_length]  # Next 12 values
        
        # Store sequences separately
        input_sequences.append([x, y] + list(input_seq))
        target_sequences.append([x, y] + list(target_seq))
        locations.append([x, y])

# Define column names
input_columns = ["x", "y"] + [f"LST_t-{i}" for i in range(sequence_length, 0, -1)]
target_columns = ["x", "y"] + [f"Target_t+{i}" for i in range(1, target_length + 1)]

# Convert to DataFrames
input_df = pd.DataFrame(input_sequences, columns=input_columns)
target_df = pd.DataFrame(target_sequences, columns=target_columns)

# %%
## THIS FUNCTION IS TO CREATE THE 10 RANDOM TRAIN-TEST SAMPLES ##

np.random.seed(5188)

# Function to create a time index
def create_time_index(df):
    bimonthly_map = {"Jan-Feb": 1, "Mar-Apr": 2, "May-Jun": 3, "Jul-Aug": 4, "Sep-Oct": 5, "Nov-Dec": 6}
    df["Year"] = df["Date"].str[-4:].astype(int)  # Extract year
    df["Period"] = df["Date"].str[:-5].map(bimonthly_map)  # Extract period and map it
    df["time_index"] = (df["Year"] - 2000) * 6 + df["Period"]  # Compute time index
    df = df.drop(columns=["Year", "Period"])  # Drop extra columns
    return df

df = create_time_index(df)

# Select 100 random unique coordinate pairs
unique_coords = df[['x', 'y']].drop_duplicates().sample(n=100, random_state=5188)
selected_df = df.merge(unique_coords, on=['x', 'y'])

# Get valid start indices for 10-year training windows
min_time = selected_df["time_index"].min()
max_time = selected_df["time_index"].max()
valid_start_times = np.arange(min_time, max_time - (10 * 6 + 2 * 6) + 1)

# Randomly sample 10 different start times
sampled_start_times = np.random.choice(valid_start_times, 10, replace=False)

# Extract train and test sets for each sampled start time
samples = []
for start_time in sampled_start_times:
    train_end_time = start_time + (10 * 6) - 1
    test_end_time = train_end_time + (2 * 6)
    
    train_set = selected_df[(selected_df["time_index"] >= start_time) & (selected_df["time_index"] <= train_end_time)]
    test_set = selected_df[(selected_df["time_index"] > train_end_time) & (selected_df["time_index"] <= test_end_time)]
    
    samples.append((train_set, test_set))


# # Save sampled train-test sets
# for i, (train_set, test_set) in enumerate(samples):
#     train_set.to_csv(f"train_sample_{i+1}.csv", index=False)
#     test_set.to_csv(f"test_sample_{i+1}.csv", index=False)

# %% [markdown]
# ### Without dropout

# %%
## THIS CODE IS TO CREATE THE LSTM ##

class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = self.fc(lstm_out)
        return out

# %%
## THIS CODE IS TO TRAIN THE LSTM ##
torch.manual_seed(5188)

# Function to prepare sequences for LSTM
def create_lstm_sequences(series, seq_length):
    X, y = [], []
    for i in range(len(series) - seq_length):
        X.append(series[i:i+seq_length])
        y.append(series[i+1:i+seq_length+1])
    return np.array(X), np.array(y)

# Training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
seq_length = 12

# Initialize RMSE tracker
rmse_stats = {
    "1st": [], "3rd": [], "6th": [], "9th": [], "12th": [], "Overall": []
}

# Iterate over each sampled train-test set
for sample_idx, (train_set, test_set) in enumerate(samples):
    value_series = train_set['Value'].values.astype(np.float32)
    test_values = test_set['Value'].values.astype(np.float32)[:12]  # Only next 12 values

    mean, std = value_series.mean(), value_series.std()
    value_series_norm = (value_series - mean) / std

    X_seq, y_seq = create_lstm_sequences(value_series_norm.reshape(-1, 1), seq_length)
    X_train = torch.tensor(X_seq, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq, dtype=torch.float32).to(device)

    model = LSTMPredictor().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        output = model(X_train)
        loss = criterion(output[:, :-1, :], y_train[:, 1:, :])
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"Sample {sample_idx+1}, Epoch {epoch}, Loss: {loss.item():.4f}")

    model.eval()
    with torch.no_grad():
        input_seq = torch.tensor(value_series_norm[-seq_length:].reshape(1, seq_length, 1), dtype=torch.float32).to(device)
        preds = []
        for _ in range(12):
            pred = model(input_seq)[:, -1:, :]
            preds.append(pred.item())
            input_seq = torch.cat((input_seq[:, 1:, :], pred), dim=1)

    preds = np.array(preds) * std + mean

    # Calculate RMSEs
    for step, label in zip([0, 2, 5, 8, 11], ["1st", "3rd", "6th", "9th", "12th"]):
        rmse = np.sqrt(mean_squared_error([test_values[step]], [preds[step]]))
        rmse_stats[label].append(rmse)

    all_rmse = np.sqrt(mean_squared_error(test_values, preds))
    rmse_stats["Overall"].append(all_rmse)

# Compute average RMSE across samples
rmse_df_10 = pd.DataFrame({k: [np.mean(v)] for k, v in rmse_stats.items()}).T
rmse_df_10.columns = ["Window = 10"]
rmse_df_10.index.name = "Forecast horizon"
print("\nAverage RMSE per forecast step:")
print(rmse_df_10)
rmse_df_10.to_csv("rmse_10.csv")
# Out:
# Sample 1, Epoch 0, Loss: 1.0039
# Sample 1, Epoch 10, Loss: 0.9063
# Sample 1, Epoch 20, Loss: 0.5093
# Sample 1, Epoch 30, Loss: 0.4710
# Sample 1, Epoch 40, Loss: 0.4384
# Sample 1, Epoch 50, Loss: 0.3916
# Sample 1, Epoch 60, Loss: 0.3445
# Sample 1, Epoch 70, Loss: 0.3009
# Sample 1, Epoch 80, Loss: 0.2770
# Sample 1, Epoch 90, Loss: 0.2622
# Sample 2, Epoch 0, Loss: 1.0007
# Sample 2, Epoch 10, Loss: 0.9146
# Sample 2, Epoch 20, Loss: 0.5336
# Sample 2, Epoch 30, Loss: 0.4962
# Sample 2, Epoch 40, Loss: 0.4622
# Sample 2, Epoch 50, Loss: 0.4095
# Sample 2, Epoch 60, Loss: 0.3565
# Sample 2, Epoch 70, Loss: 0.3084
# Sample 2, Epoch 80, Loss: 0.2826
# Sample 2, Epoch 90, Loss: 0.2660
# Sample 3, Epoch 0, Loss: 1.0073
# Sample 3, Epoch 10, Loss: 0.9377
# Sample 3, Epoch 20, Loss: 0.6019
# Sample 3, Epoch 30, Loss: 0.5269
# Sample 3, Epoch 40, Loss: 0.4582
# Sample 3, Epoch 50, Loss: 0.3935
# Sample 3, Epoch 60, Loss: 0.3326
# Sample 3, Epoch 70, Loss: 0.2913
# Sample 3, Epoch 80, Loss: 0.2691
# Sample 3, Epoch 90, Loss: 0.2523
# Sample 4, Epoch 0, Loss: 1.0034
# Sample 4, Epoch 10, Loss: 0.9327
# Sample 4, Epoch 20, Loss: 0.5545
# Sample 4, Epoch 30, Loss: 0.4942
# Sample 4, Epoch 40, Loss: 0.4625
# Sample 4, Epoch 50, Loss: 0.4128
# Sample 4, Epoch 60, Loss: 0.3660
# Sample 4, Epoch 70, Loss: 0.3216
# Sample 4, Epoch 80, Loss: 0.2922
# Sample 4, Epoch 90, Loss: 0.2774
# Sample 5, Epoch 0, Loss: 1.0183
# Sample 5, Epoch 10, Loss: 0.9372
# Sample 5, Epoch 20, Loss: 0.6415
# Sample 5, Epoch 30, Loss: 0.5457
# Sample 5, Epoch 40, Loss: 0.4610
# Sample 5, Epoch 50, Loss: 0.4095
# Sample 5, Epoch 60, Loss: 0.3652
# Sample 5, Epoch 70, Loss: 0.3403
# Sample 5, Epoch 80, Loss: 0.3217
# Sample 5, Epoch 90, Loss: 0.3081
# Sample 6, Epoch 0, Loss: 1.0364
# Sample 6, Epoch 10, Loss: 0.9417
# Sample 6, Epoch 20, Loss: 0.6319
# Sample 6, Epoch 30, Loss: 0.5293
# Sample 6, Epoch 40, Loss: 0.4442
# Sample 6, Epoch 50, Loss: 0.3860
# Sample 6, Epoch 60, Loss: 0.3352
# Sample 6, Epoch 70, Loss: 0.3022
# Sample 6, Epoch 80, Loss: 0.2796
# Sample 6, Epoch 90, Loss: 0.2635
# Sample 7, Epoch 0, Loss: 1.0085
# Sample 7, Epoch 10, Loss: 0.9257
# Sample 7, Epoch 20, Loss: 0.5576
# Sample 7, Epoch 30, Loss: 0.5098
# Sample 7, Epoch 40, Loss: 0.4691
# Sample 7, Epoch 50, Loss: 0.4086
# Sample 7, Epoch 60, Loss: 0.3503
# Sample 7, Epoch 70, Loss: 0.3002
# Sample 7, Epoch 80, Loss: 0.2779
# Sample 7, Epoch 90, Loss: 0.2592
# Sample 8, Epoch 0, Loss: 1.0000
# Sample 8, Epoch 10, Loss: 0.9022
# Sample 8, Epoch 20, Loss: 0.5570
# Sample 8, Epoch 30, Loss: 0.5073
# Sample 8, Epoch 40, Loss: 0.4709
# Sample 8, Epoch 50, Loss: 0.4308
# Sample 8, Epoch 60, Loss: 0.3950
# Sample 8, Epoch 70, Loss: 0.3661
# Sample 8, Epoch 80, Loss: 0.3476
# Sample 8, Epoch 90, Loss: 0.3342
# Sample 9, Epoch 0, Loss: 1.0039
# Sample 9, Epoch 10, Loss: 0.8881
# Sample 9, Epoch 20, Loss: 0.5175
# Sample 9, Epoch 30, Loss: 0.4730
# Sample 9, Epoch 40, Loss: 0.4339
# Sample 9, Epoch 50, Loss: 0.3804
# Sample 9, Epoch 60, Loss: 0.3298
# Sample 9, Epoch 70, Loss: 0.2954
# Sample 9, Epoch 80, Loss: 0.2769
# Sample 9, Epoch 90, Loss: 0.2608
# Sample 10, Epoch 0, Loss: 1.0075
# Sample 10, Epoch 10, Loss: 0.9284
# Sample 10, Epoch 20, Loss: 0.5329
# Sample 10, Epoch 30, Loss: 0.4848
# Sample 10, Epoch 40, Loss: 0.4517
# Sample 10, Epoch 50, Loss: 0.4011
# Sample 10, Epoch 60, Loss: 0.3522
# Sample 10, Epoch 70, Loss: 0.3076
# Sample 10, Epoch 80, Loss: 0.2814
# Sample 10, Epoch 90, Loss: 0.2653
#
# Average RMSE per forecast step:
#                   Window = 10
# Forecast horizon
# 1st                  2.084234
# 3rd                  1.522499
# 6th                  1.631671
# 9th                  1.598111
# 12th                 1.513376
# Overall              1.760370

# %% [markdown]
# ### With dropout

# %%
## THIS CODE IS TO CREATE THE LSTM ##

class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1, dropout=0.2):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers, 
            batch_first=True, dropout=dropout
        )
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = self.fc(lstm_out)
        return out

# %%
## THIS CODE IS TO TRAIN THE LSTM ##
torch.manual_seed(5188)

# Function to prepare sequences for LSTM
def create_lstm_sequences(series, seq_length):
    X, y = [], []
    for i in range(len(series) - seq_length):
        X.append(series[i:i+seq_length])
        y.append(series[i+1:i+seq_length+1])
    return np.array(X), np.array(y)

# Training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
seq_length = 12

# Initialize RMSE tracker
rmse_stats = {
    "1st": [], "3rd": [], "6th": [], "9th": [], "12th": [], "Overall": []
}

# Iterate over each sampled train-test set
for sample_idx, (train_set, test_set) in enumerate(samples):
    
    value_series = train_set['Value'].values.astype(np.float32)
    test_values = test_set['Value'].values.astype(np.float32)[:12]  # Only next 12 values

    mean, std = value_series.mean(), value_series.std()
    value_series_norm = (value_series - mean) / std

    X_seq, y_seq = create_lstm_sequences(value_series_norm.reshape(-1, 1), seq_length)
    X_train = torch.tensor(X_seq, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq, dtype=torch.float32).to(device)

    model = LSTMPredictor().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-6)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        output = model(X_train)
        loss = criterion(output[:, :-1, :], y_train[:, 1:, :])
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"Sample {sample_idx+1}, Epoch {epoch}, Loss: {loss.item():.4f}")

    model.eval()
    with torch.no_grad():
        input_seq = torch.tensor(value_series_norm[-seq_length:].reshape(1, seq_length, 1), dtype=torch.float32).to(device)
        preds = []
        for _ in range(12):
            pred = model(input_seq)[:, -1:, :]
            preds.append(pred.item())
            input_seq = torch.cat((input_seq[:, 1:, :], pred), dim=1)

    preds = np.array(preds) * std + mean

    # Calculate RMSEs
    for step, label in zip([0, 2, 5, 8, 11], ["1st", "3rd", "6th", "9th", "12th"]):
        rmse = np.sqrt(mean_squared_error([test_values[step]], [preds[step]]))
        rmse_stats[label].append(rmse)

    all_rmse = np.sqrt(mean_squared_error(test_values, preds))
    rmse_stats["Overall"].append(all_rmse)

# Compute average RMSE across samples
rmse_df_10_dropout = pd.DataFrame({k: [np.mean(v)] for k, v in rmse_stats.items()}).T
rmse_df_10_dropout.columns = ["Window = 10"]
rmse_df_10_dropout.index.name = "Forecast horizon"
print("\nAverage RMSE per forecast step:")
print(rmse_df_10_dropout)
rmse_df_10_dropout.to_csv("rmse_dropout_10.csv")
# Out:
# Sample 1, Epoch 0, Loss: 1.0039
# Sample 1, Epoch 10, Loss: 0.9064
# Sample 1, Epoch 20, Loss: 0.5107
# Sample 1, Epoch 30, Loss: 0.4722
# Sample 1, Epoch 40, Loss: 0.4400
# Sample 1, Epoch 50, Loss: 0.3941
# Sample 1, Epoch 60, Loss: 0.3465
# Sample 1, Epoch 70, Loss: 0.3051
# Sample 1, Epoch 80, Loss: 0.2813
# Sample 1, Epoch 90, Loss: 0.2678
# Sample 2, Epoch 0, Loss: 1.0017
# Sample 2, Epoch 10, Loss: 0.9249
# Sample 2, Epoch 20, Loss: 0.5436
# Sample 2, Epoch 30, Loss: 0.4846
# Sample 2, Epoch 40, Loss: 0.4498
# Sample 2, Epoch 50, Loss: 0.3980
# Sample 2, Epoch 60, Loss: 0.3490
# Sample 2, Epoch 70, Loss: 0.3102
# Sample 2, Epoch 80, Loss: 0.2886
# Sample 2, Epoch 90, Loss: 0.2738
# Sample 3, Epoch 0, Loss: 1.0052
# Sample 3, Epoch 10, Loss: 0.9078
# Sample 3, Epoch 20, Loss: 0.5524
# Sample 3, Epoch 30, Loss: 0.4889
# Sample 3, Epoch 40, Loss: 0.4383
# Sample 3, Epoch 50, Loss: 0.3768
# Sample 3, Epoch 60, Loss: 0.3252
# Sample 3, Epoch 70, Loss: 0.2889
# Sample 3, Epoch 80, Loss: 0.2688
# Sample 3, Epoch 90, Loss: 0.2546
# Sample 4, Epoch 0, Loss: 1.0082
# Sample 4, Epoch 10, Loss: 0.9373
# Sample 4, Epoch 20, Loss: 0.5627
# Sample 4, Epoch 30, Loss: 0.5020
# Sample 4, Epoch 40, Loss: 0.4628
# Sample 4, Epoch 50, Loss: 0.4088
# Sample 4, Epoch 60, Loss: 0.3591
# Sample 4, Epoch 70, Loss: 0.3174
# Sample 4, Epoch 80, Loss: 0.2941
# Sample 4, Epoch 90, Loss: 0.2784
# Sample 5, Epoch 0, Loss: 0.9998
# Sample 5, Epoch 10, Loss: 0.9051
# Sample 5, Epoch 20, Loss: 0.5566
# Sample 5, Epoch 30, Loss: 0.5015
# Sample 5, Epoch 40, Loss: 0.4686
# Sample 5, Epoch 50, Loss: 0.4240
# Sample 5, Epoch 60, Loss: 0.3844
# Sample 5, Epoch 70, Loss: 0.3549
# Sample 5, Epoch 80, Loss: 0.3365
# Sample 5, Epoch 90, Loss: 0.3250
# Sample 6, Epoch 0, Loss: 1.0155
# Sample 6, Epoch 10, Loss: 0.9304
# Sample 6, Epoch 20, Loss: 0.6038
# Sample 6, Epoch 30, Loss: 0.5004
# Sample 6, Epoch 40, Loss: 0.4440
# Sample 6, Epoch 50, Loss: 0.3850
# Sample 6, Epoch 60, Loss: 0.3329
# Sample 6, Epoch 70, Loss: 0.2976
# Sample 6, Epoch 80, Loss: 0.2807
# Sample 6, Epoch 90, Loss: 0.2658
# Sample 7, Epoch 0, Loss: 1.0026
# Sample 7, Epoch 10, Loss: 0.8949
# Sample 7, Epoch 20, Loss: 0.5480
# Sample 7, Epoch 30, Loss: 0.4779
# Sample 7, Epoch 40, Loss: 0.4186
# Sample 7, Epoch 50, Loss: 0.3522
# Sample 7, Epoch 60, Loss: 0.3054
# Sample 7, Epoch 70, Loss: 0.2780
# Sample 7, Epoch 80, Loss: 0.2596
# Sample 7, Epoch 90, Loss: 0.2456
# Sample 8, Epoch 0, Loss: 1.0013
# Sample 8, Epoch 10, Loss: 0.9128
# Sample 8, Epoch 20, Loss: 0.5567
# Sample 8, Epoch 30, Loss: 0.5181
# Sample 8, Epoch 40, Loss: 0.4880
# Sample 8, Epoch 50, Loss: 0.4489
# Sample 8, Epoch 60, Loss: 0.4116
# Sample 8, Epoch 70, Loss: 0.3775
# Sample 8, Epoch 80, Loss: 0.3565
# Sample 8, Epoch 90, Loss: 0.3434
# Sample 9, Epoch 0, Loss: 1.0194
# Sample 9, Epoch 10, Loss: 0.9235
# Sample 9, Epoch 20, Loss: 0.5793
# Sample 9, Epoch 30, Loss: 0.5087
# Sample 9, Epoch 40, Loss: 0.4378
# Sample 9, Epoch 50, Loss: 0.3762
# Sample 9, Epoch 60, Loss: 0.3225
# Sample 9, Epoch 70, Loss: 0.2877
# Sample 9, Epoch 80, Loss: 0.2684
# Sample 9, Epoch 90, Loss: 0.2536
# Sample 10, Epoch 0, Loss: 1.0121
# Sample 10, Epoch 10, Loss: 0.9275
# Sample 10, Epoch 20, Loss: 0.5538
# Sample 10, Epoch 30, Loss: 0.4952
# Sample 10, Epoch 40, Loss: 0.4506
# Sample 10, Epoch 50, Loss: 0.3946
# Sample 10, Epoch 60, Loss: 0.3441
# Sample 10, Epoch 70, Loss: 0.3088
# Sample 10, Epoch 80, Loss: 0.2839
# Sample 10, Epoch 90, Loss: 0.2680
#
# Average RMSE per forecast step:
#                   Window = 10
# Forecast horizon
# 1st                  2.008615
# 3rd                  1.481001
# 6th                  1.555977
# 9th                  1.325104
# 12th                 1.486089
# Overall              1.684088
