# %%
import torch
from torch import nn
import torch.optim as optim
import torch.nn as nn
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from dateutil.relativedelta import relativedelta
import geopandas as gpd
from shapely.geometry import Polygon, Point
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("../../../Data/Final/Imputation/changi_imp_final.csv")
print(df.head())
# Out:
#             x         y          Date      Value
# 0  103.964566  1.350459  Mar-Apr 2000  23.775064
# 1  103.964566  1.351269  Mar-Apr 2000  23.403744
# 2  103.964566  1.352079  Mar-Apr 2000  22.966872
# 3  103.964566  1.352889  Mar-Apr 2000  22.417757
# 4  103.965377  1.348838  Mar-Apr 2000  23.699749

# %%
## THIS CODE IS TO REFORMAT THE TIME INDEX IN THE DATASET ##

# Function to create a time index
def create_time_index(df):
    bimonthly_map = {"Jan-Feb": 1, "Mar-Apr": 2, "May-Jun": 3, "Jul-Aug": 4, "Sep-Oct": 5, "Nov-Dec": 6}
    
    df["Year"] = df["Date"].str[-4:].astype(int)  # Extract year
    df["Period"] = df["Date"].str[:-5].map(bimonthly_map)  # Extract period and map it

    df["time_index"] = (df["Year"] - 2000) * 6 + df["Period"]  # Compute time index
    df = df.drop(columns=["Year", "Period"])  # Drop extra columns
    
    return df

# Apply time index transformation
df = create_time_index(df)

# %%
## THIS CODE IS TO FILTER A RANDOM SAMPLE OF 100 COORDINATES INSIDE A BOUNDING BOX ##

np.random.seed(5188)  # Set random seed for reproducibility

# Define the bounding box (replace with actual values)
coordinates = [103.98, 104.05, 1.32, 1.38]  # Example bounding box for Changi
bbox = Polygon([
    (coordinates[0], coordinates[2]), 
    (coordinates[1], coordinates[2]), 
    (coordinates[1], coordinates[3]), 
    (coordinates[0], coordinates[3]), 
    (coordinates[0], coordinates[2])
])

# Function to filter 100 coordinates inside bounding box
def filter_by_geography(df, bbox, seed=5188, n=100):
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df["x"], df["y"]), crs="EPSG:4326")
    filtered_gdf = gdf[gdf.within(bbox)]
    
    # Select 100 unique coordinates
    sampled_coords = filtered_gdf[['x', 'y']].drop_duplicates().sample(n=n, random_state=seed)
    filtered_df = df.merge(sampled_coords, on=['x', 'y'])
    
    return filtered_df

# Apply filtering
df = filter_by_geography(df, bbox)

# Keep only relevant columns
df = df[["x", "y", "Date", "Value", "time_index"]]

# # Save the filtered dataset
# df.to_csv("filtered_changi.csv", index=False)
# print("Filtered dataset saved as filtered_changi.csv")

## To ensure that the same 100 coordinates are used check the unique (x,y) pairs in the filtered dataset ##
unique_coords = df[['x', 'y']].drop_duplicates()
print(f"Number of unique coordinates: {len(unique_coords)}")
# Out:
# Number of unique coordinates: 100

# %%
## THIS CODE IS TO EXTRACT ALL POSSIBLE WINDOWS OF SIZE = 11 ##

# Define sequence length
sequence_length = 11 * 6 
target_length = 12  # Predict the next 12 time steps

# Group by (x, y) and process each time series separately
grouped = df.groupby(["x", "y"])

# Lists to store input sequences and target sequences separately
input_sequences = []
target_sequences = []
locations = []

# Iterate over each coordinate group
for (x, y), group in grouped:
    # Sort by time index
    group = group.sort_values(by="time_index")

    # Extract LST values
    values = group["Value"].values

    # Generate sequences
    for i in range(len(values) - sequence_length - target_length + 1):
        input_seq = values[i : i + sequence_length]  # Past values
        target_seq = values[i + sequence_length : i + sequence_length + target_length]  # Next 12 values
        
        # Store sequences separately
        input_sequences.append([x, y] + list(input_seq))
        target_sequences.append([x, y] + list(target_seq))
        locations.append([x, y])

# Define column names
input_columns = ["x", "y"] + [f"LST_t-{i}" for i in range(sequence_length, 0, -1)]
target_columns = ["x", "y"] + [f"Target_t+{i}" for i in range(1, target_length + 1)]

# Convert to DataFrames
input_df = pd.DataFrame(input_sequences, columns=input_columns)
target_df = pd.DataFrame(target_sequences, columns=target_columns)

# %%
## THIS FUNCTION IS TO CREATE THE 10 RANDOM TRAIN-TEST SAMPLES ##

np.random.seed(5188)

# Function to create a time index
def create_time_index(df):
    bimonthly_map = {"Jan-Feb": 1, "Mar-Apr": 2, "May-Jun": 3, "Jul-Aug": 4, "Sep-Oct": 5, "Nov-Dec": 6}
    df["Year"] = df["Date"].str[-4:].astype(int)  # Extract year
    df["Period"] = df["Date"].str[:-5].map(bimonthly_map)  # Extract period and map it
    df["time_index"] = (df["Year"] - 2000) * 6 + df["Period"]  # Compute time index
    df = df.drop(columns=["Year", "Period"])  # Drop extra columns
    return df

df = create_time_index(df)

# Select 100 random unique coordinate pairs
unique_coords = df[['x', 'y']].drop_duplicates().sample(n=100, random_state=5188)
selected_df = df.merge(unique_coords, on=['x', 'y'])

# Get valid start indices for 9-year training windows
min_time = selected_df["time_index"].min()
max_time = selected_df["time_index"].max()
valid_start_times = np.arange(min_time, max_time - (11 * 6 + 2 * 6) + 1)

# Randomly sample 10 different start times
sampled_start_times = np.random.choice(valid_start_times, 10, replace=False)

# Extract train and test sets for each sampled start time
samples = []
for start_time in sampled_start_times:
    train_end_time = start_time + (11 * 6) - 1
    test_end_time = train_end_time + (2 * 6)
    
    train_set = selected_df[(selected_df["time_index"] >= start_time) & (selected_df["time_index"] <= train_end_time)]
    test_set = selected_df[(selected_df["time_index"] > train_end_time) & (selected_df["time_index"] <= test_end_time)]
    
    samples.append((train_set, test_set))


# # Save sampled train-test sets
# for i, (train_set, test_set) in enumerate(samples):
#     train_set.to_csv(f"train_sample_{i+1}.csv", index=False)
#     test_set.to_csv(f"test_sample_{i+1}.csv", index=False)

# %% [markdown]
# ### Without dropout

# %%
## THIS CODE IS TO CREATE THE LSTM ##

class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = self.fc(lstm_out)
        return out

# %%
## THIS CODE IS TO TRAIN THE LSTM ##
torch.manual_seed(5188)

# Function to prepare sequences for LSTM
def create_lstm_sequences(series, seq_length):
    X, y = [], []
    for i in range(len(series) - seq_length):
        X.append(series[i:i+seq_length])
        y.append(series[i+1:i+seq_length+1])
    return np.array(X), np.array(y)

# Training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
seq_length = 12

# Initialize RMSE tracker
rmse_stats = {
    "1st": [], "3rd": [], "6th": [], "9th": [], "12th": [], "Overall": []
}

# Iterate over each sampled train-test set
for sample_idx, (train_set, test_set) in enumerate(samples):
    value_series = train_set['Value'].values.astype(np.float32)
    test_values = test_set['Value'].values.astype(np.float32)[:12]  # Only next 12 values

    mean, std = value_series.mean(), value_series.std()
    value_series_norm = (value_series - mean) / std

    X_seq, y_seq = create_lstm_sequences(value_series_norm.reshape(-1, 1), seq_length)
    X_train = torch.tensor(X_seq, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq, dtype=torch.float32).to(device)

    model = LSTMPredictor().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        output = model(X_train)
        loss = criterion(output[:, :-1, :], y_train[:, 1:, :])
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"Sample {sample_idx+1}, Epoch {epoch}, Loss: {loss.item():.4f}")

    model.eval()
    with torch.no_grad():
        input_seq = torch.tensor(value_series_norm[-seq_length:].reshape(1, seq_length, 1), dtype=torch.float32).to(device)
        preds = []
        for _ in range(12):
            pred = model(input_seq)[:, -1:, :]
            preds.append(pred.item())
            input_seq = torch.cat((input_seq[:, 1:, :], pred), dim=1)

    preds = np.array(preds) * std + mean

    # Calculate RMSEs
    for step, label in zip([0, 2, 5, 8, 11], ["1st", "3rd", "6th", "9th", "12th"]):
        rmse = np.sqrt(mean_squared_error([test_values[step]], [preds[step]]))
        rmse_stats[label].append(rmse)

    all_rmse = np.sqrt(mean_squared_error(test_values, preds))
    rmse_stats["Overall"].append(all_rmse)

# Compute average RMSE across samples
rmse_df_11 = pd.DataFrame({k: [np.mean(v)] for k, v in rmse_stats.items()}).T
rmse_df_11.columns = ["Window = 11"]
rmse_df_11.index.name = "Forecast horizon"
print("\nAverage RMSE per forecast step:")
print(rmse_df_11)
rmse_df_11.to_csv("rmse_11.csv")
# Out:
# Sample 1, Epoch 0, Loss: 1.0052
# Sample 1, Epoch 10, Loss: 0.9100
# Sample 1, Epoch 20, Loss: 0.5227
# Sample 1, Epoch 30, Loss: 0.4850
# Sample 1, Epoch 40, Loss: 0.4525
# Sample 1, Epoch 50, Loss: 0.4054
# Sample 1, Epoch 60, Loss: 0.3582
# Sample 1, Epoch 70, Loss: 0.3155
# Sample 1, Epoch 80, Loss: 0.2934
# Sample 1, Epoch 90, Loss: 0.2786
# Sample 2, Epoch 0, Loss: 1.0020
# Sample 2, Epoch 10, Loss: 0.9160
# Sample 2, Epoch 20, Loss: 0.5421
# Sample 2, Epoch 30, Loss: 0.5046
# Sample 2, Epoch 40, Loss: 0.4686
# Sample 2, Epoch 50, Loss: 0.4124
# Sample 2, Epoch 60, Loss: 0.3562
# Sample 2, Epoch 70, Loss: 0.3064
# Sample 2, Epoch 80, Loss: 0.2824
# Sample 2, Epoch 90, Loss: 0.2654
# Sample 3, Epoch 0, Loss: 1.0063
# Sample 3, Epoch 10, Loss: 0.9363
# Sample 3, Epoch 20, Loss: 0.5849
# Sample 3, Epoch 30, Loss: 0.5136
# Sample 3, Epoch 40, Loss: 0.4453
# Sample 3, Epoch 50, Loss: 0.3872
# Sample 3, Epoch 60, Loss: 0.3350
# Sample 3, Epoch 70, Loss: 0.3001
# Sample 3, Epoch 80, Loss: 0.2747
# Sample 3, Epoch 90, Loss: 0.2582
# Sample 4, Epoch 0, Loss: 1.0031
# Sample 4, Epoch 10, Loss: 0.9320
# Sample 4, Epoch 20, Loss: 0.5496
# Sample 4, Epoch 30, Loss: 0.4887
# Sample 4, Epoch 40, Loss: 0.4567
# Sample 4, Epoch 50, Loss: 0.4075
# Sample 4, Epoch 60, Loss: 0.3614
# Sample 4, Epoch 70, Loss: 0.3171
# Sample 4, Epoch 80, Loss: 0.2862
# Sample 4, Epoch 90, Loss: 0.2710
# Sample 5, Epoch 0, Loss: 1.0187
# Sample 5, Epoch 10, Loss: 0.9388
# Sample 5, Epoch 20, Loss: 0.6433
# Sample 5, Epoch 30, Loss: 0.5496
# Sample 5, Epoch 40, Loss: 0.4677
# Sample 5, Epoch 50, Loss: 0.4126
# Sample 5, Epoch 60, Loss: 0.3661
# Sample 5, Epoch 70, Loss: 0.3401
# Sample 5, Epoch 80, Loss: 0.3222
# Sample 5, Epoch 90, Loss: 0.3086
# Sample 6, Epoch 0, Loss: 1.0357
# Sample 6, Epoch 10, Loss: 0.9406
# Sample 6, Epoch 20, Loss: 0.6295
# Sample 6, Epoch 30, Loss: 0.5251
# Sample 6, Epoch 40, Loss: 0.4402
# Sample 6, Epoch 50, Loss: 0.3829
# Sample 6, Epoch 60, Loss: 0.3322
# Sample 6, Epoch 70, Loss: 0.2985
# Sample 6, Epoch 80, Loss: 0.2756
# Sample 6, Epoch 90, Loss: 0.2592
# Sample 7, Epoch 0, Loss: 1.0070
# Sample 7, Epoch 10, Loss: 0.9294
# Sample 7, Epoch 20, Loss: 0.5743
# Sample 7, Epoch 30, Loss: 0.5314
# Sample 7, Epoch 40, Loss: 0.5025
# Sample 7, Epoch 50, Loss: 0.4579
# Sample 7, Epoch 60, Loss: 0.4150
# Sample 7, Epoch 70, Loss: 0.3752
# Sample 7, Epoch 80, Loss: 0.3528
# Sample 7, Epoch 90, Loss: 0.3375
# Sample 8, Epoch 0, Loss: 0.9987
# Sample 8, Epoch 10, Loss: 0.8944
# Sample 8, Epoch 20, Loss: 0.5216
# Sample 8, Epoch 30, Loss: 0.4698
# Sample 8, Epoch 40, Loss: 0.4311
# Sample 8, Epoch 50, Loss: 0.3812
# Sample 8, Epoch 60, Loss: 0.3348
# Sample 8, Epoch 70, Loss: 0.2967
# Sample 8, Epoch 80, Loss: 0.2776
# Sample 8, Epoch 90, Loss: 0.2622
# Sample 9, Epoch 0, Loss: 1.0029
# Sample 9, Epoch 10, Loss: 0.8870
# Sample 9, Epoch 20, Loss: 0.5133
# Sample 9, Epoch 30, Loss: 0.4694
# Sample 9, Epoch 40, Loss: 0.4305
# Sample 9, Epoch 50, Loss: 0.3768
# Sample 9, Epoch 60, Loss: 0.3257
# Sample 9, Epoch 70, Loss: 0.2911
# Sample 9, Epoch 80, Loss: 0.2729
# Sample 9, Epoch 90, Loss: 0.2568
# Sample 10, Epoch 0, Loss: 1.0079
# Sample 10, Epoch 10, Loss: 0.9292
# Sample 10, Epoch 20, Loss: 0.5379
# Sample 10, Epoch 30, Loss: 0.4915
# Sample 10, Epoch 40, Loss: 0.4589
# Sample 10, Epoch 50, Loss: 0.4078
# Sample 10, Epoch 60, Loss: 0.3579
# Sample 10, Epoch 70, Loss: 0.3125
# Sample 10, Epoch 80, Loss: 0.2864
# Sample 10, Epoch 90, Loss: 0.2707
#
# Average RMSE per forecast step:
#                   Window = 11
# Forecast horizon
# 1st                  4.148146
# 3rd                  2.900478
# 6th                  2.762529
# 9th                  3.710457
# 12th                 3.375065
# Overall              3.537110

# %% [markdown]
# ### With dropout

# %%
## THIS CODE IS TO CREATE THE LSTM ##

class LSTMPredictor(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=3, output_size=1, dropout=0.2):
        super(LSTMPredictor, self).__init__()
        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers, 
            batch_first=True, dropout=dropout
        )
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = self.fc(lstm_out)
        return out

# %%
## THIS CODE IS TO TRAIN THE LSTM ##
torch.manual_seed(5188)

# Function to prepare sequences for LSTM
def create_lstm_sequences(series, seq_length):
    X, y = [], []
    for i in range(len(series) - seq_length):
        X.append(series[i:i+seq_length])
        y.append(series[i+1:i+seq_length+1])
    return np.array(X), np.array(y)

# Training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
seq_length = 12

# Initialize RMSE tracker
rmse_stats = {
    "1st": [], "3rd": [], "6th": [], "9th": [], "12th": [], "Overall": []
}

# Iterate over each sampled train-test set
for sample_idx, (train_set, test_set) in enumerate(samples):
    
    value_series = train_set['Value'].values.astype(np.float32)
    test_values = test_set['Value'].values.astype(np.float32)[:12]  # Only next 12 values

    mean, std = value_series.mean(), value_series.std()
    value_series_norm = (value_series - mean) / std

    X_seq, y_seq = create_lstm_sequences(value_series_norm.reshape(-1, 1), seq_length)
    X_train = torch.tensor(X_seq, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq, dtype=torch.float32).to(device)

    model = LSTMPredictor().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-6)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        output = model(X_train)
        loss = criterion(output[:, :-1, :], y_train[:, 1:, :])
        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"Sample {sample_idx+1}, Epoch {epoch}, Loss: {loss.item():.4f}")

    model.eval()
    with torch.no_grad():
        input_seq = torch.tensor(value_series_norm[-seq_length:].reshape(1, seq_length, 1), dtype=torch.float32).to(device)
        preds = []
        for _ in range(12):
            pred = model(input_seq)[:, -1:, :]
            preds.append(pred.item())
            input_seq = torch.cat((input_seq[:, 1:, :], pred), dim=1)

    preds = np.array(preds) * std + mean

    # Calculate RMSEs
    for step, label in zip([0, 2, 5, 8, 11], ["1st", "3rd", "6th", "9th", "12th"]):
        rmse = np.sqrt(mean_squared_error([test_values[step]], [preds[step]]))
        rmse_stats[label].append(rmse)

    all_rmse = np.sqrt(mean_squared_error(test_values, preds))
    rmse_stats["Overall"].append(all_rmse)

# Compute average RMSE across samples
rmse_df_11_dropout = pd.DataFrame({k: [np.mean(v)] for k, v in rmse_stats.items()}).T
rmse_df_11_dropout.columns = ["Window = 11"]
rmse_df_11_dropout.index.name = "Forecast horizon"
print("\nAverage RMSE per forecast step:")
print(rmse_df_11_dropout)
rmse_df_11_dropout.to_csv("rmse_dropout_11.csv")
# Out:
# Sample 1, Epoch 0, Loss: 1.0053
# Sample 1, Epoch 10, Loss: 0.9103
# Sample 1, Epoch 20, Loss: 0.5238
# Sample 1, Epoch 30, Loss: 0.4865
# Sample 1, Epoch 40, Loss: 0.4544
# Sample 1, Epoch 50, Loss: 0.4075
# Sample 1, Epoch 60, Loss: 0.3610
# Sample 1, Epoch 70, Loss: 0.3198
# Sample 1, Epoch 80, Loss: 0.2982
# Sample 1, Epoch 90, Loss: 0.2835
# Sample 2, Epoch 0, Loss: 1.0020
# Sample 2, Epoch 10, Loss: 0.9164
# Sample 2, Epoch 20, Loss: 0.5439
# Sample 2, Epoch 30, Loss: 0.5063
# Sample 2, Epoch 40, Loss: 0.4701
# Sample 2, Epoch 50, Loss: 0.4145
# Sample 2, Epoch 60, Loss: 0.3588
# Sample 2, Epoch 70, Loss: 0.3102
# Sample 2, Epoch 80, Loss: 0.2869
# Sample 2, Epoch 90, Loss: 0.2714
# Sample 3, Epoch 0, Loss: 1.0063
# Sample 3, Epoch 10, Loss: 0.9365
# Sample 3, Epoch 20, Loss: 0.5864
# Sample 3, Epoch 30, Loss: 0.5155
# Sample 3, Epoch 40, Loss: 0.4468
# Sample 3, Epoch 50, Loss: 0.3894
# Sample 3, Epoch 60, Loss: 0.3381
# Sample 3, Epoch 70, Loss: 0.3037
# Sample 3, Epoch 80, Loss: 0.2796
# Sample 3, Epoch 90, Loss: 0.2644
# Sample 4, Epoch 0, Loss: 1.0031
# Sample 4, Epoch 10, Loss: 0.9323
# Sample 4, Epoch 20, Loss: 0.5512
# Sample 4, Epoch 30, Loss: 0.4902
# Sample 4, Epoch 40, Loss: 0.4580
# Sample 4, Epoch 50, Loss: 0.4092
# Sample 4, Epoch 60, Loss: 0.3635
# Sample 4, Epoch 70, Loss: 0.3200
# Sample 4, Epoch 80, Loss: 0.2902
# Sample 4, Epoch 90, Loss: 0.2758
# Sample 5, Epoch 0, Loss: 1.0187
# Sample 5, Epoch 10, Loss: 0.9390
# Sample 5, Epoch 20, Loss: 0.6442
# Sample 5, Epoch 30, Loss: 0.5510
# Sample 5, Epoch 40, Loss: 0.4691
# Sample 5, Epoch 50, Loss: 0.4151
# Sample 5, Epoch 60, Loss: 0.3695
# Sample 5, Epoch 70, Loss: 0.3446
# Sample 5, Epoch 80, Loss: 0.3270
# Sample 5, Epoch 90, Loss: 0.3144
# Sample 6, Epoch 0, Loss: 1.0356
# Sample 6, Epoch 10, Loss: 0.9410
# Sample 6, Epoch 20, Loss: 0.6304
# Sample 6, Epoch 30, Loss: 0.5270
# Sample 6, Epoch 40, Loss: 0.4422
# Sample 6, Epoch 50, Loss: 0.3856
# Sample 6, Epoch 60, Loss: 0.3357
# Sample 6, Epoch 70, Loss: 0.3027
# Sample 6, Epoch 80, Loss: 0.2807
# Sample 6, Epoch 90, Loss: 0.2659
# Sample 7, Epoch 0, Loss: 1.0070
# Sample 7, Epoch 10, Loss: 0.9297
# Sample 7, Epoch 20, Loss: 0.5758
# Sample 7, Epoch 30, Loss: 0.5326
# Sample 7, Epoch 40, Loss: 0.5039
# Sample 7, Epoch 50, Loss: 0.4591
# Sample 7, Epoch 60, Loss: 0.4168
# Sample 7, Epoch 70, Loss: 0.3775
# Sample 7, Epoch 80, Loss: 0.3560
# Sample 7, Epoch 90, Loss: 0.3411
# Sample 8, Epoch 0, Loss: 0.9986
# Sample 8, Epoch 10, Loss: 0.8948
# Sample 8, Epoch 20, Loss: 0.5226
# Sample 8, Epoch 30, Loss: 0.4716
# Sample 8, Epoch 40, Loss: 0.4334
# Sample 8, Epoch 50, Loss: 0.3836
# Sample 8, Epoch 60, Loss: 0.3380
# Sample 8, Epoch 70, Loss: 0.3008
# Sample 8, Epoch 80, Loss: 0.2822
# Sample 8, Epoch 90, Loss: 0.2682
# Sample 9, Epoch 0, Loss: 1.0028
# Sample 9, Epoch 10, Loss: 0.8873
# Sample 9, Epoch 20, Loss: 0.5145
# Sample 9, Epoch 30, Loss: 0.4713
# Sample 9, Epoch 40, Loss: 0.4328
# Sample 9, Epoch 50, Loss: 0.3796
# Sample 9, Epoch 60, Loss: 0.3300
# Sample 9, Epoch 70, Loss: 0.2960
# Sample 9, Epoch 80, Loss: 0.2778
# Sample 9, Epoch 90, Loss: 0.2631
# Sample 10, Epoch 0, Loss: 1.0079
# Sample 10, Epoch 10, Loss: 0.9295
# Sample 10, Epoch 20, Loss: 0.5398
# Sample 10, Epoch 30, Loss: 0.4934
# Sample 10, Epoch 40, Loss: 0.4605
# Sample 10, Epoch 50, Loss: 0.4098
# Sample 10, Epoch 60, Loss: 0.3603
# Sample 10, Epoch 70, Loss: 0.3161
# Sample 10, Epoch 80, Loss: 0.2903
# Sample 10, Epoch 90, Loss: 0.2755
#
# Average RMSE per forecast step:
#                   Window = 11
# Forecast horizon
# 1st                  4.152526
# 3rd                  2.907505
# 6th                  2.758280
# 9th                  3.712593
# 12th                 3.370993
# Overall              3.536331
